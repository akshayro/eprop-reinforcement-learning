# %%
import numpy as np
import matplotlib.pyplot as plt
import spikes4 as spk4
import snn_models

num_trial = 10
last_acc = np.zeros(num_trial)

for i in range(num_trial): 

    #%% parameters
    time_step = 1 # 1ms time resolution    

    lr = 0.002 # learning rate 0.005
    thr = 0.6 # v threshold
    tau_out = 3 # output decay time constant /// unit: ms
    kappa = np.exp(-time_step/tau_out) # output decay
    tau_mem = 20 # v decay time constant /// unit: ms
    alpha = np.exp(-time_step/tau_mem) # v decay
    beta = 0.2 # adaptation increment 
    tau_a = 200 # adaptation decay time constant /// unit: ms
    rho = np.exp(-time_step/(tau_a+1e-12)) # adaptation decay
    t_ref = 2 # refractory period /// unit: ms    

    decays = np.array([lr, thr, alpha, beta, kappa, rho, t_ref]) # save as a vector    

    #%% input data generation
    nb_inputs, nb_hidden, nb_outputs  = 40, 100, 2 # number of neurons
    batch_size = 256
    nb_batch = 10 # number of batches
    nb_data = batch_size*nb_batch # =256*10
    n_train = batch_size*(nb_batch-1) # =256*9
    n_test = batch_size # =256*1
    nb_steps = 500 # simulation duration (ms)
    dur_stim = 100 # stimulation duration (ms)    

    x = np.zeros((nb_batch,batch_size,nb_steps,40)) # input dta train
    y1hot = np.zeros((nb_batch,batch_size,nb_steps,2)) # target data (1hot encoding)
    y = np.zeros((nb_batch,batch_size,nb_steps,)) # target data (0 for left, 1 for right, 0.5 otherwise)    

    for batch_idx in range(nb_batch):
        for b in range(batch_size):
            y_data = 0.5*np.ones((nb_steps)) 
            y_data1hot = np.zeros((nb_steps, 2))
            cue_on = np.zeros((nb_steps),dtype=bool) # learning cue, True when learing cue is on.
            
            prob_noise = 1*(time_step/1000) #!!! noise has 1Hz spike frequency
            x_data = np.random.choice(2, size=(nb_steps,nb_inputs),p=[1-prob_noise,prob_noise])
            
            t_stim = np.random.randint(0,350) # stimuli given random time interval [0,350]ms
            t_learn = 400 # learning cue starts at 400ms
            prob_stim = 40*(time_step/1000) #!!! input has 40Hz spike frequency
            x_stim = np.random.choice(2, size=(dur_stim,int(nb_inputs/4)),p=[1-prob_stim,prob_stim]).astype(float)
            l_or_r = np.random.choice(2) # left or right?
            x_data[t_stim:t_stim+dur_stim, int(nb_inputs/4)*l_or_r:int(nb_inputs/4)*l_or_r+int(nb_inputs/4)] = x_stim
            
            x_learn = np.random.choice(2, size=(dur_stim,int(nb_inputs/4)),p=[1-prob_stim,prob_stim]).astype(float)
            x_data[t_learn:t_learn+dur_stim, int(nb_inputs/4)*2:int(nb_inputs/4)*2+int(nb_inputs/4)] = x_learn
            
            y_data1hot[t_learn:t_learn+dur_stim, l_or_r] = 1
            cue_on[t_learn:t_learn+dur_stim] = True
            y_data[t_learn:t_learn+dur_stim] = l_or_r    

            x[batch_idx,b] = x_data
            y[batch_idx,b] = y_data
            y1hot[batch_idx,b] = y_data1hot
    print('data generated.')
    stim = 2*y-1 # same as y, but -1 for left, 1 for right, and 0 otherwise    

    print(x.shape)
    print(y.shape)
    print(y1hot.shape)    

    #%% initialize weight
    weight_scale = 10*(1.0-alpha) #!!!
    w1 = np.random.normal(size=(nb_inputs,nb_hidden), loc=0.0, scale=weight_scale/np.sqrt(nb_inputs)) # input-->hidden
    w2 = np.random.normal(size=(nb_hidden,nb_outputs), loc=0.0, scale=weight_scale/np.sqrt(nb_hidden)) # hidden-->hidden
    #bias = np.random.normal(size=(nb_outputs), loc=0.0, scale=weight_scale/np.sqrt(nb_outputs)) # output bias
    bias = np.zeros(nb_outputs) # output bias
    B = np.random.normal(size=(nb_outputs,nb_hidden), loc=0.0, scale=weight_scale/np.sqrt(nb_outputs)) #!!! random e-prop    

    #%% recurrent weights (choose only one)
    ############### (1) random network ###############
    # wr = np.random.normal(size=(nb_hidden,nb_hidden), loc=0.0, scale=weight_scale/np.sqrt(nb_hidden)) # hidden-->output
    # np.fill_diagonal(wr,0) # no self connectivity    

    ############### (2) E/I network ###############
    import graph_analysis
    nb_e = int(nb_hidden*0.8)
    nb_i = nb_hidden - nb_e
    ind_fromi = np.zeros((nb_hidden,nb_hidden),dtype=bool)
    ind_fromi[nb_e:,:] = True # index of inhibitory neurons    

    wr, xy, cdens = graph_analysis.aij_distance2d([1000,1000], [250,150], nb_e, nb_i, np.array([[1,-1],[1,-1]]), cself=False, plot=False, randomseed=None)
    wr = wr.T
    wr *= 0.05 # scaling    

    plt.imshow(wr) # visualize initial weights    

    #%% compile (1st run numba is slow)
    x_tmp, y1hot_tmp, cue_on_tmp = x[0,:,:3,:].copy(),y1hot[0,:,:3,:].copy(),cue_on[:3].copy()
    loss, out_rec, dw1, dwr, dw2, dbias, v_rec, z_rec, a_rec = snn_models.lif_eprop(w1,wr,w2,bias,B,x_tmp, y1hot_tmp, cue_on_tmp,decays)
    print('compile done.')    

    #%% run train
    dw1_past = np.zeros((nb_inputs,nb_hidden))
    dw2_past = np.zeros((nb_hidden,nb_outputs))
    dwr_past = np.zeros((nb_hidden,nb_hidden))
    dbias_past = np.zeros((nb_outputs,))
    loss_train, fr_train, acc_train, spktr, wrs, atr = [],[],[],[],[],[]
    loss_valid, fr_valid, acc_valid = [],[],[]
    n_epochs = 50
    for epoch in range(n_epochs): # 100
        ######################### train #########################
        loss_batch,acc_batch,fr_batch = np.zeros((nb_batch-1,)), np.zeros((nb_batch-1,)), np.zeros((nb_batch-1,))
        for batch_idx in range(nb_batch-1): # batch_idx = 0
            x_batch,y1hot_batch,y_batch = x[batch_idx],y1hot[batch_idx],y[batch_idx]
            loss, out_rec, dw1, dwr, dw2, dbias, v_rec, z_rec, a_rec = snn_models.lif_eprop(w1,wr,w2,bias,B,x_batch,y1hot_batch,cue_on,decays)
            dw1_past = 0.9*dw1_past + np.mean(dw1,0) #!!! momentum=0.9
            dw2_past = 0.9*dw2_past + np.mean(dw2,0) #!!! momentum=0.9
            dwr_past = 0.9*dwr_past + np.mean(dwr,0) #!!! momentum=0.9
            dbias_past = 0.9*dbias_past + np.mean(dbias,0) #!!! momentum=0.9 #AKSHAY
            
            w1 += dw1_past # input-->hidden update
            w2 += dw2_past # hidden-->hidden update
            wr += dwr_past # hidden-->output update
#            bias += dbias_past # bias update #AKSHAY
            
            # w1 += np.mean(dw1,0) # these are for no-momentum update (slow learning)
            # w2 += np.mean(dw2,0)
            # wr += np.mean(dwr,0)
            # bias += np.mean(dbias,0)
            # np.fill_diagonal(wr,0) # no-self connectivity    

            #!!! below 5 lines are valid only for E/I network (uncomment when using random network) 
            ind_negative = wr<0
            ind = ind_negative*(~ind_fromi) # find negative & exciatory neurons
            wr[ind] = 0. # force the negative weights to 0
            ind = (~ind_negative)*ind_fromi # find positive & inhibitory neurons
            wr[ind] = 0. # force the positive weights to 0
            
            pi = np.exp(out_rec[:,cue_on,:])/np.exp(out_rec[:,cue_on,:]).sum(2).reshape(batch_size,dur_stim,1) # sfotmax /// [batch_size,dur_stim,2]
            pi_m = pi.mean(1)
            acc_batch[batch_idx] = (np.argmax(pi_m,axis=1) == y_batch[:,cue_on][:,-1]).mean() # save cc
            
            loss_batch[batch_idx] = loss.mean() # save loss
            fr_batch[batch_idx] = 1000*z_rec.mean() # save firing rate
        loss_train.append(loss_batch.mean()) # save loss 
        acc_train.append(acc_batch.mean()) # save acc
        fr_train.append(fr_batch.mean()) # save firing rate
        print('EPOCH %d TRAIN) loss: %0.4f, acc: %0.4f, fr: %0.4f Hz' %(epoch, loss_train[epoch], acc_train[epoch], fr_train[epoch]))    

        ######################### validate #########################
        x_batch,y1hot_batch,y_batch = x[-1],y1hot[-1],y[-1] # the last batch is for valid data
        loss, out_rec, dw1, dwr, dw2, dbias, v_rec, z_rec, a_rec = snn_models.lif_eprop(w1,wr,w2,bias,B,x_batch,y1hot_batch,cue_on,decays)
        
        
        pi = np.exp(out_rec[:,cue_on,:])/np.exp(out_rec[:,cue_on,:]).sum(2).reshape(batch_size,dur_stim,1) # softmax /// [batch_size,dur_stim,2]
        pi_m = pi.mean(1)
        acc_valid.append((np.argmax(pi_m,axis=1) == y_batch[:,cue_on][:,-1]).mean()) # save acc
        
        loss_valid.append(loss.mean()) # save loss
        fr_valid.append(1000*z_rec.mean()) # save firing rate
        print('EPOCH %d VALID) loss: %0.4f, acc: %0.4f, fr: %0.4f Hz' %(epoch, loss_valid[epoch], acc_valid[epoch], fr_valid[epoch]))
            
        spktr.append(z_rec[0]) # save spike train /// save one batch data only to save memory
        atr.append(a_rec[0]) # save a trace
        wrs.append(wr.copy()) # save weights
        
        ######################### save best weights #########################
        if loss_valid[-1] == min(loss_valid): # or you can use acc criteria instead
            w1_save,w2_save,wr_save,bias_save = w1.copy(),w2.copy(),wr.copy(),bias.copy()
            epoch_best = epoch
    spktr = np.stack(spktr,0)
    atr = np.stack(atr,0)
    wrs = np.stack(wrs,0)
    N = int(n_epochs/8) # epoch interval for plotting
    
    last_acc[i] = acc_valid[-1]
    print('num_trial=', i)
# Out:
# data generated.
# (10, 256, 500, 40)
# (10, 256, 500)
# (10, 256, 500, 2)
# compile done.
# EPOCH 0 TRAIN) loss: 69.3312, acc: 0.5035, fr: 0.5178 Hz
# EPOCH 0 VALID) loss: 69.3304, acc: 0.5273, fr: 0.5330 Hz
# EPOCH 1 TRAIN) loss: 69.3052, acc: 0.5295, fr: 0.5751 Hz
# EPOCH 1 VALID) loss: 69.3167, acc: 0.4766, fr: 0.6570 Hz
# EPOCH 2 TRAIN) loss: 69.2791, acc: 0.5417, fr: 0.7492 Hz
# EPOCH 2 VALID) loss: 69.2942, acc: 0.5078, fr: 0.8960 Hz
# EPOCH 3 TRAIN) loss: 69.2651, acc: 0.5230, fr: 1.0284 Hz
# EPOCH 3 VALID) loss: 69.2391, acc: 0.5234, fr: 1.2440 Hz
# EPOCH 4 TRAIN) loss: 69.2082, acc: 0.5551, fr: 1.4451 Hz
# EPOCH 4 VALID) loss: 69.0681, acc: 0.6523, fr: 1.7413 Hz
# EPOCH 5 TRAIN) loss: 68.8881, acc: 0.6671, fr: 2.0389 Hz
# EPOCH 5 VALID) loss: 68.6003, acc: 0.6328, fr: 2.4551 Hz
# EPOCH 6 TRAIN) loss: 68.3668, acc: 0.6159, fr: 2.7701 Hz
# EPOCH 6 VALID) loss: 68.1065, acc: 0.6602, fr: 3.1393 Hz
# EPOCH 7 TRAIN) loss: 67.8648, acc: 0.7227, fr: 3.3395 Hz
# EPOCH 7 VALID) loss: 67.7038, acc: 0.8438, fr: 3.5718 Hz
# EPOCH 8 TRAIN) loss: 67.3643, acc: 0.8863, fr: 3.7299 Hz
# EPOCH 8 VALID) loss: 67.1431, acc: 0.9219, fr: 3.9452 Hz
# EPOCH 9 TRAIN) loss: 67.1374, acc: 0.9036, fr: 4.1144 Hz
# EPOCH 9 VALID) loss: 66.9202, acc: 0.9375, fr: 4.2798 Hz
# EPOCH 10 TRAIN) loss: 66.8667, acc: 0.9006, fr: 4.4493 Hz
# EPOCH 10 VALID) loss: 66.6999, acc: 0.9297, fr: 4.6059 Hz
# EPOCH 11 TRAIN) loss: 66.6436, acc: 0.8824, fr: 4.8434 Hz
# EPOCH 11 VALID) loss: 66.5181, acc: 0.9062, fr: 5.1064 Hz
# EPOCH 12 TRAIN) loss: 66.3076, acc: 0.8767, fr: 5.3362 Hz
# EPOCH 12 VALID) loss: 66.2818, acc: 0.9102, fr: 5.5772 Hz
# EPOCH 13 TRAIN) loss: 66.0672, acc: 0.8845, fr: 5.7793 Hz
# EPOCH 13 VALID) loss: 66.0836, acc: 0.9219, fr: 5.9877 Hz
# EPOCH 14 TRAIN) loss: 65.8427, acc: 0.9041, fr: 6.1665 Hz
# EPOCH 14 VALID) loss: 65.6645, acc: 0.9219, fr: 6.4416 Hz
# EPOCH 15 TRAIN) loss: 65.5294, acc: 0.8898, fr: 6.5955 Hz
# EPOCH 15 VALID) loss: 65.3051, acc: 0.9492, fr: 6.8223 Hz
# EPOCH 16 TRAIN) loss: 65.3961, acc: 0.9032, fr: 6.9984 Hz
# EPOCH 16 VALID) loss: 65.2720, acc: 0.9336, fr: 7.1581 Hz
# EPOCH 17 TRAIN) loss: 65.2253, acc: 0.8997, fr: 7.3650 Hz
# EPOCH 17 VALID) loss: 65.2024, acc: 0.9609, fr: 7.5894 Hz
# EPOCH 18 TRAIN) loss: 65.1234, acc: 0.9062, fr: 7.8224 Hz
# EPOCH 18 VALID) loss: 65.2461, acc: 0.9531, fr: 8.0209 Hz
# EPOCH 19 TRAIN) loss: 65.1235, acc: 0.9084, fr: 8.2529 Hz
# EPOCH 19 VALID) loss: 65.2429, acc: 0.9531, fr: 8.4612 Hz
# EPOCH 20 TRAIN) loss: 65.0963, acc: 0.9149, fr: 8.6535 Hz
# EPOCH 20 VALID) loss: 65.5192, acc: 0.9688, fr: 8.8296 Hz
# EPOCH 21 TRAIN) loss: 65.3378, acc: 0.9149, fr: 9.0014 Hz
# EPOCH 21 VALID) loss: 65.4306, acc: 0.9570, fr: 9.2144 Hz
# EPOCH 22 TRAIN) loss: 65.5632, acc: 0.9084, fr: 9.3924 Hz
# EPOCH 22 VALID) loss: 65.9206, acc: 0.9727, fr: 9.5969 Hz
# EPOCH 23 TRAIN) loss: 65.6082, acc: 0.9119, fr: 9.8209 Hz
# EPOCH 23 VALID) loss: 66.1088, acc: 0.9531, fr: 10.0385 Hz
# EPOCH 24 TRAIN) loss: 65.8575, acc: 0.8893, fr: 10.3547 Hz
# EPOCH 24 VALID) loss: 66.0389, acc: 0.8750, fr: 10.6004 Hz
# EPOCH 25 TRAIN) loss: 66.0126, acc: 0.8607, fr: 11.0581 Hz
# EPOCH 25 VALID) loss: 66.3327, acc: 0.7422, fr: 11.4845 Hz
# EPOCH 26 TRAIN) loss: 66.2873, acc: 0.7999, fr: 12.0253 Hz
# EPOCH 26 VALID) loss: 66.8890, acc: 0.6055, fr: 12.6016 Hz
# EPOCH 27 TRAIN) loss: 66.9036, acc: 0.7357, fr: 13.2280 Hz
# EPOCH 27 VALID) loss: 66.7402, acc: 0.6719, fr: 13.9289 Hz
# EPOCH 28 TRAIN) loss: 67.2733, acc: 0.6979, fr: 14.4723 Hz
# EPOCH 28 VALID) loss: 65.8865, acc: 0.9102, fr: 15.0059 Hz
# EPOCH 29 TRAIN) loss: 66.8215, acc: 0.7391, fr: 15.4108 Hz
# EPOCH 29 VALID) loss: 66.4859, acc: 0.8086, fr: 15.9310 Hz
# EPOCH 30 TRAIN) loss: 66.1146, acc: 0.7817, fr: 16.3508 Hz
# EPOCH 30 VALID) loss: 66.5777, acc: 0.8516, fr: 16.7797 Hz
# EPOCH 31 TRAIN) loss: 65.6098, acc: 0.9167, fr: 17.2449 Hz
# EPOCH 31 VALID) loss: 65.7312, acc: 0.9375, fr: 17.6552 Hz
# EPOCH 32 TRAIN) loss: 65.7061, acc: 0.8464, fr: 18.2025 Hz
# EPOCH 32 VALID) loss: 65.9105, acc: 0.8867, fr: 18.6614 Hz
# EPOCH 33 TRAIN) loss: 65.4792, acc: 0.8954, fr: 19.1683 Hz
# EPOCH 33 VALID) loss: 65.5915, acc: 0.9453, fr: 19.6326 Hz
# EPOCH 34 TRAIN) loss: 65.3835, acc: 0.8793, fr: 20.0877 Hz
# EPOCH 34 VALID) loss: 65.0943, acc: 0.9180, fr: 20.5006 Hz
# EPOCH 35 TRAIN) loss: 65.3044, acc: 0.8737, fr: 20.9385 Hz
# EPOCH 35 VALID) loss: 65.1172, acc: 0.9297, fr: 21.1997 Hz
# EPOCH 36 TRAIN) loss: 65.1616, acc: 0.8885, fr: 21.7795 Hz
# EPOCH 4 TRAIN) loss: 69.1221, acc: 0.5165, fr: 1.3387 Hz
# EPOCH 4 VALID) loss: 69.3511, acc: 0.4336, fr: 1.5131 Hz
# EPOCH 5 TRAIN) loss: 68.8528, acc: 0.5178, fr: 1.6828 Hz
# EPOCH 5 VALID) loss: 69.1431, acc: 0.4336, fr: 1.8941 Hz
# EPOCH 6 TRAIN) loss: 68.1506, acc: 0.5399, fr: 2.1042 Hz
# EPOCH 6 VALID) loss: 68.4473, acc: 0.4961, fr: 2.3987 Hz
# EPOCH 7 TRAIN) loss: 66.8394, acc: 0.6402, fr: 2.6526 Hz
# EPOCH 7 VALID) loss: 67.1197, acc: 0.6602, fr: 3.0110 Hz
# EPOCH 8 TRAIN) loss: 65.4429, acc: 0.7995, fr: 3.2129 Hz
# EPOCH 8 VALID) loss: 65.7381, acc: 0.8789, fr: 3.5320 Hz
# EPOCH 9 TRAIN) loss: 64.7568, acc: 0.9214, fr: 3.6282 Hz
# EPOCH 9 VALID) loss: 65.0908, acc: 0.9570, fr: 3.8764 Hz
# EPOCH 10 TRAIN) loss: 64.3317, acc: 0.9514, fr: 3.8945 Hz
# EPOCH 10 VALID) loss: 64.6519, acc: 0.9531, fr: 4.0502 Hz
# EPOCH 11 TRAIN) loss: 63.9453, acc: 0.9484, fr: 4.0599 Hz
# EPOCH 11 VALID) loss: 64.4399, acc: 0.9492, fr: 4.2350 Hz
# EPOCH 12 TRAIN) loss: 63.5026, acc: 0.9579, fr: 4.2156 Hz
# EPOCH 12 VALID) loss: 63.9499, acc: 0.9609, fr: 4.4035 Hz
# EPOCH 13 TRAIN) loss: 63.3105, acc: 0.9518, fr: 4.4018 Hz
# EPOCH 13 VALID) loss: 63.6137, acc: 0.9648, fr: 4.6035 Hz
# EPOCH 14 TRAIN) loss: 62.9765, acc: 0.9614, fr: 4.6041 Hz
# EPOCH 14 VALID) loss: 63.3161, acc: 0.9492, fr: 4.8248 Hz
# EPOCH 15 TRAIN) loss: 62.7774, acc: 0.9596, fr: 4.8166 Hz
# EPOCH 15 VALID) loss: 63.7674, acc: 0.9570, fr: 5.0265 Hz
# EPOCH 16 TRAIN) loss: 62.6982, acc: 0.9536, fr: 5.0048 Hz
# EPOCH 16 VALID) loss: 63.4025, acc: 0.9492, fr: 5.2108 Hz
# EPOCH 17 TRAIN) loss: 62.8615, acc: 0.9523, fr: 5.1748 Hz
# EPOCH 17 VALID) loss: 63.4361, acc: 0.9414, fr: 5.3873 Hz
# EPOCH 18 TRAIN) loss: 62.8306, acc: 0.9397, fr: 5.3337 Hz
# EPOCH 18 VALID) loss: 63.3862, acc: 0.9531, fr: 5.5188 Hz
# EPOCH 19 TRAIN) loss: 62.8562, acc: 0.9488, fr: 5.4827 Hz
# EPOCH 19 VALID) loss: 63.1930, acc: 0.9336, fr: 5.7042 Hz
# EPOCH 20 TRAIN) loss: 62.9325, acc: 0.9436, fr: 5.6613 Hz
# EPOCH 20 VALID) loss: 63.3705, acc: 0.9258, fr: 5.8601 Hz
# EPOCH 21 TRAIN) loss: 62.9258, acc: 0.9392, fr: 5.8175 Hz
# EPOCH 21 VALID) loss: 63.1297, acc: 0.9336, fr: 6.0127 Hz
# EPOCH 22 TRAIN) loss: 62.9167, acc: 0.9345, fr: 5.9878 Hz
# EPOCH 22 VALID) loss: 62.8401, acc: 0.9609, fr: 6.2229 Hz
# EPOCH 23 TRAIN) loss: 62.7167, acc: 0.9319, fr: 6.1788 Hz
# EPOCH 23 VALID) loss: 63.3363, acc: 0.9336, fr: 6.4341 Hz
# EPOCH 24 TRAIN) loss: 62.8055, acc: 0.9388, fr: 6.3865 Hz
# EPOCH 24 VALID) loss: 63.4563, acc: 0.9414, fr: 6.6352 Hz
# EPOCH 25 TRAIN) loss: 62.8476, acc: 0.9327, fr: 6.5980 Hz
# EPOCH 25 VALID) loss: 63.6514, acc: 0.9258, fr: 6.8480 Hz
# EPOCH 26 TRAIN) loss: 62.8011, acc: 0.9319, fr: 6.7952 Hz
# EPOCH 26 VALID) loss: 63.7820, acc: 0.9336, fr: 7.0374 Hz
# EPOCH 27 TRAIN) loss: 62.7504, acc: 0.9319, fr: 7.0063 Hz
# EPOCH 27 VALID) loss: 62.9340, acc: 0.9492, fr: 7.2420 Hz
# EPOCH 28 TRAIN) loss: 62.6248, acc: 0.9323, fr: 7.2114 Hz
# EPOCH 28 VALID) loss: 63.3088, acc: 0.9180, fr: 7.4876 Hz
# EPOCH 29 TRAIN) loss: 62.5005, acc: 0.9245, fr: 7.4460 Hz
# EPOCH 29 VALID) loss: 62.6535, acc: 0.9336, fr: 7.6955 Hz
# EPOCH 30 TRAIN) loss: 62.5005, acc: 0.9249, fr: 7.7097 Hz
# EPOCH 30 VALID) loss: 63.0036, acc: 0.9375, fr: 8.0336 Hz
# EPOCH 31 TRAIN) loss: 62.6395, acc: 0.9214, fr: 7.9788 Hz
# EPOCH 31 VALID) loss: 62.8609, acc: 0.9336, fr: 8.3327 Hz
# EPOCH 32 TRAIN) loss: 62.6211, acc: 0.9158, fr: 8.2537 Hz
# EPOCH 32 VALID) loss: 62.4196, acc: 0.9375, fr: 8.5829 Hz
# EPOCH 33 TRAIN) loss: 62.4041, acc: 0.9201, fr: 8.5156 Hz
# EPOCH 33 VALID) loss: 62.6546, acc: 0.9102, fr: 8.8613 Hz
# EPOCH 34 TRAIN) loss: 62.5220, acc: 0.9197, fr: 8.7787 Hz
# EPOCH 34 VALID) loss: 62.9296, acc: 0.9258, fr: 9.1415 Hz
# EPOCH 35 TRAIN) loss: 62.5151, acc: 0.9180, fr: 9.0975 Hz
# EPOCH 35 VALID) loss: 63.1584, acc: 0.9062, fr: 9.4452 Hz
# EPOCH 36 TRAIN) loss: 62.5803, acc: 0.9180, fr: 9.4159 Hz
# EPOCH 36 VALID) loss: 62.7287, acc: 0.9180, fr: 9.7495 Hz
# EPOCH 37 TRAIN) loss: 62.8688, acc: 0.9123, fr: 9.7297 Hz
# EPOCH 37 VALID) loss: 62.8373, acc: 0.9141, fr: 10.0946 Hz
# EPOCH 5 VALID) loss: 68.3536, acc: 0.5508, fr: 2.0892 Hz
# EPOCH 6 TRAIN) loss: 68.3531, acc: 0.5109, fr: 2.4793 Hz
# EPOCH 6 VALID) loss: 67.5908, acc: 0.5703, fr: 2.7798 Hz
# EPOCH 7 TRAIN) loss: 67.8792, acc: 0.5525, fr: 3.2012 Hz
# EPOCH 7 VALID) loss: 66.8853, acc: 0.6523, fr: 3.5238 Hz
# EPOCH 8 TRAIN) loss: 67.5352, acc: 0.7339, fr: 3.8468 Hz
# EPOCH 8 VALID) loss: 67.1704, acc: 0.9023, fr: 4.0367 Hz
# EPOCH 9 TRAIN) loss: 67.3148, acc: 0.8854, fr: 4.3102 Hz
# EPOCH 9 VALID) loss: 66.9216, acc: 0.8398, fr: 4.5004 Hz
# EPOCH 10 TRAIN) loss: 67.0181, acc: 0.8190, fr: 4.7720 Hz
# EPOCH 10 VALID) loss: 66.4167, acc: 0.8594, fr: 4.9563 Hz
# EPOCH 11 TRAIN) loss: 66.5996, acc: 0.8685, fr: 5.2262 Hz
# EPOCH 11 VALID) loss: 66.1666, acc: 0.8633, fr: 5.4088 Hz
# EPOCH 12 TRAIN) loss: 66.3764, acc: 0.8555, fr: 5.6685 Hz
# EPOCH 12 VALID) loss: 65.9823, acc: 0.8750, fr: 5.8516 Hz
# EPOCH 13 TRAIN) loss: 66.2235, acc: 0.8720, fr: 6.0652 Hz
# EPOCH 13 VALID) loss: 65.8217, acc: 0.8555, fr: 6.1677 Hz
# EPOCH 14 TRAIN) loss: 66.0480, acc: 0.8750, fr: 6.3447 Hz
# EPOCH 14 VALID) loss: 65.5879, acc: 0.8516, fr: 6.4261 Hz
# EPOCH 15 TRAIN) loss: 65.9609, acc: 0.8728, fr: 6.5849 Hz
# EPOCH 15 VALID) loss: 65.4281, acc: 0.8633, fr: 6.6366 Hz
# EPOCH 16 TRAIN) loss: 65.9367, acc: 0.8789, fr: 6.8239 Hz
# EPOCH 16 VALID) loss: 65.3975, acc: 0.8711, fr: 6.9059 Hz
# EPOCH 17 TRAIN) loss: 65.8660, acc: 0.8759, fr: 7.0682 Hz
# EPOCH 17 VALID) loss: 65.1870, acc: 0.8438, fr: 7.1755 Hz
# EPOCH 18 TRAIN) loss: 65.8579, acc: 0.8733, fr: 7.3344 Hz
# EPOCH 18 VALID) loss: 65.3904, acc: 0.8320, fr: 7.4297 Hz
# EPOCH 19 TRAIN) loss: 65.8162, acc: 0.8733, fr: 7.5893 Hz
# EPOCH 19 VALID) loss: 65.4145, acc: 0.8125, fr: 7.6972 Hz
# EPOCH 20 TRAIN) loss: 65.8580, acc: 0.8737, fr: 7.8525 Hz
# EPOCH 20 VALID) loss: 65.1272, acc: 0.8242, fr: 7.9154 Hz
# EPOCH 21 TRAIN) loss: 65.8874, acc: 0.8767, fr: 8.1192 Hz
# EPOCH 21 VALID) loss: 65.1767, acc: 0.8086, fr: 8.1610 Hz
# EPOCH 22 TRAIN) loss: 65.8963, acc: 0.8620, fr: 8.3856 Hz
# EPOCH 22 VALID) loss: 65.3286, acc: 0.7656, fr: 8.4306 Hz
# EPOCH 23 TRAIN) loss: 66.0872, acc: 0.8433, fr: 8.6488 Hz
# EPOCH 23 VALID) loss: 65.1832, acc: 0.7617, fr: 8.6523 Hz
# EPOCH 24 TRAIN) loss: 65.9802, acc: 0.8372, fr: 8.9083 Hz
# EPOCH 24 VALID) loss: 65.2782, acc: 0.7461, fr: 8.9073 Hz
# EPOCH 25 TRAIN) loss: 66.0616, acc: 0.8194, fr: 9.1324 Hz
# EPOCH 25 VALID) loss: 65.0147, acc: 0.7500, fr: 9.1803 Hz
# EPOCH 26 TRAIN) loss: 66.0966, acc: 0.8003, fr: 9.3641 Hz
# EPOCH 26 VALID) loss: 65.0718, acc: 0.7344, fr: 9.3984 Hz
# EPOCH 27 TRAIN) loss: 66.2066, acc: 0.7704, fr: 9.5535 Hz
# EPOCH 27 VALID) loss: 65.2187, acc: 0.7227, fr: 9.5518 Hz
# EPOCH 28 TRAIN) loss: 66.2368, acc: 0.7422, fr: 9.7168 Hz
# EPOCH 28 VALID) loss: 65.1723, acc: 0.7266, fr: 9.7130 Hz
# EPOCH 29 TRAIN) loss: 66.2551, acc: 0.7283, fr: 9.9064 Hz
# EPOCH 29 VALID) loss: 64.9247, acc: 0.7070, fr: 9.9007 Hz
# EPOCH 30 TRAIN) loss: 66.3613, acc: 0.7127, fr: 10.1005 Hz
# EPOCH 30 VALID) loss: 65.0157, acc: 0.7148, fr: 10.1072 Hz
# EPOCH 31 TRAIN) loss: 66.4712, acc: 0.7053, fr: 10.2852 Hz
# EPOCH 31 VALID) loss: 64.9619, acc: 0.7227, fr: 10.3136 Hz
# EPOCH 32 TRAIN) loss: 66.6305, acc: 0.6979, fr: 10.4613 Hz
# EPOCH 32 VALID) loss: 64.9917, acc: 0.7148, fr: 10.4478 Hz
# EPOCH 33 TRAIN) loss: 66.9130, acc: 0.6814, fr: 10.5763 Hz
# EPOCH 33 VALID) loss: 65.4373, acc: 0.7344, fr: 10.4613 Hz
# EPOCH 34 TRAIN) loss: 67.4859, acc: 0.6693, fr: 10.5969 Hz
# EPOCH 34 VALID) loss: 66.0946, acc: 0.7305, fr: 10.4644 Hz
# EPOCH 35 TRAIN) loss: 67.9907, acc: 0.6580, fr: 10.5760 Hz
# EPOCH 35 VALID) loss: 65.9482, acc: 0.7305, fr: 10.4731 Hz
# EPOCH 36 TRAIN) loss: 68.0159, acc: 0.6398, fr: 10.6472 Hz
# EPOCH 36 VALID) loss: 65.6572, acc: 0.7383, fr: 10.6288 Hz
# EPOCH 37 TRAIN) loss: 67.8643, acc: 0.6385, fr: 10.7985 Hz
# EPOCH 37 VALID) loss: 65.4503, acc: 0.7930, fr: 10.8298 Hz
# EPOCH 38 TRAIN) loss: 67.4166, acc: 0.6571, fr: 11.0352 Hz
# EPOCH 38 VALID) loss: 65.1391, acc: 0.8359, fr: 11.0530 Hz
# EPOCH 39 TRAIN) loss: 67.0479, acc: 0.6775, fr: 11.3074 Hz
# EPOCH 39 VALID) loss: 65.0464, acc: 0.9414, fr: 11.3728 Hz
# EPOCH 7 VALID) loss: 66.3888, acc: 0.9375, fr: 3.3593 Hz
# EPOCH 8 TRAIN) loss: 65.9176, acc: 0.9462, fr: 3.6195 Hz
# EPOCH 8 VALID) loss: 65.5805, acc: 0.9180, fr: 3.8189 Hz
# EPOCH 9 TRAIN) loss: 65.5296, acc: 0.9536, fr: 4.0278 Hz
# EPOCH 9 VALID) loss: 65.3906, acc: 0.9570, fr: 4.1549 Hz
# EPOCH 10 TRAIN) loss: 65.4441, acc: 0.9714, fr: 4.3262 Hz
# EPOCH 10 VALID) loss: 65.4098, acc: 0.9570, fr: 4.3655 Hz
# EPOCH 11 TRAIN) loss: 65.0523, acc: 0.9696, fr: 4.4730 Hz
# EPOCH 11 VALID) loss: 65.1137, acc: 0.9453, fr: 4.4747 Hz
# EPOCH 12 TRAIN) loss: 65.0674, acc: 0.9661, fr: 4.6629 Hz
# EPOCH 12 VALID) loss: 64.6758, acc: 0.9570, fr: 4.7635 Hz
# EPOCH 13 TRAIN) loss: 64.9832, acc: 0.9683, fr: 4.9595 Hz
# EPOCH 13 VALID) loss: 65.0050, acc: 0.9492, fr: 5.1109 Hz
# EPOCH 14 TRAIN) loss: 64.7283, acc: 0.9666, fr: 5.2736 Hz
# EPOCH 14 VALID) loss: 64.6903, acc: 0.9414, fr: 5.3999 Hz
# EPOCH 15 TRAIN) loss: 64.6009, acc: 0.9644, fr: 5.5401 Hz
# EPOCH 15 VALID) loss: 64.5500, acc: 0.9453, fr: 5.6423 Hz
# EPOCH 16 TRAIN) loss: 64.2746, acc: 0.9596, fr: 5.7279 Hz
# EPOCH 16 VALID) loss: 63.7951, acc: 0.9570, fr: 5.8098 Hz
# EPOCH 17 TRAIN) loss: 63.9558, acc: 0.9566, fr: 5.8505 Hz
# EPOCH 17 VALID) loss: 63.9230, acc: 0.9258, fr: 5.9398 Hz
# EPOCH 18 TRAIN) loss: 63.6817, acc: 0.9657, fr: 5.9845 Hz
# EPOCH 18 VALID) loss: 63.6944, acc: 0.9414, fr: 6.0823 Hz
# EPOCH 19 TRAIN) loss: 63.3396, acc: 0.9622, fr: 6.1755 Hz
# EPOCH 19 VALID) loss: 63.4896, acc: 0.9297, fr: 6.3570 Hz
# EPOCH 20 TRAIN) loss: 63.2141, acc: 0.9618, fr: 6.4692 Hz
# EPOCH 20 VALID) loss: 62.9214, acc: 0.9609, fr: 6.7638 Hz
# EPOCH 21 TRAIN) loss: 63.2575, acc: 0.9631, fr: 6.8491 Hz
# EPOCH 21 VALID) loss: 63.3332, acc: 0.9258, fr: 7.0996 Hz
# EPOCH 22 TRAIN) loss: 62.9909, acc: 0.9523, fr: 7.2797 Hz
# EPOCH 22 VALID) loss: 62.8733, acc: 0.9414, fr: 7.5805 Hz
# EPOCH 23 TRAIN) loss: 62.8565, acc: 0.9544, fr: 7.7891 Hz
# EPOCH 23 VALID) loss: 63.1444, acc: 0.8906, fr: 8.0864 Hz
# EPOCH 24 TRAIN) loss: 62.8533, acc: 0.9462, fr: 8.2791 Hz
# EPOCH 24 VALID) loss: 62.8117, acc: 0.8984, fr: 8.5555 Hz
# EPOCH 25 TRAIN) loss: 62.7457, acc: 0.9414, fr: 8.7593 Hz
# EPOCH 25 VALID) loss: 62.7806, acc: 0.9219, fr: 9.0760 Hz
# EPOCH 26 TRAIN) loss: 62.4139, acc: 0.9514, fr: 9.2824 Hz
# EPOCH 26 VALID) loss: 62.4348, acc: 0.9102, fr: 9.6396 Hz
# EPOCH 27 TRAIN) loss: 62.5757, acc: 0.9440, fr: 9.8409 Hz
# EPOCH 27 VALID) loss: 62.0865, acc: 0.9062, fr: 10.2024 Hz
# EPOCH 28 TRAIN) loss: 62.4163, acc: 0.9449, fr: 10.5009 Hz
# EPOCH 28 VALID) loss: 62.4593, acc: 0.8711, fr: 10.9000 Hz
# EPOCH 29 TRAIN) loss: 62.6368, acc: 0.9288, fr: 11.2087 Hz
# EPOCH 29 VALID) loss: 62.8108, acc: 0.8516, fr: 11.7079 Hz
# EPOCH 30 TRAIN) loss: 62.6723, acc: 0.9219, fr: 12.0305 Hz
# EPOCH 30 VALID) loss: 63.2137, acc: 0.8164, fr: 12.5704 Hz
# EPOCH 31 TRAIN) loss: 63.3003, acc: 0.8989, fr: 12.9420 Hz
# EPOCH 31 VALID) loss: 64.3417, acc: 0.7969, fr: 13.4133 Hz
# EPOCH 32 TRAIN) loss: 63.9652, acc: 0.8832, fr: 13.8245 Hz
# EPOCH 32 VALID) loss: 66.2897, acc: 0.7305, fr: 14.3279 Hz
# EPOCH 33 TRAIN) loss: 65.1191, acc: 0.8550, fr: 14.8218 Hz
# EPOCH 33 VALID) loss: 67.3590, acc: 0.6836, fr: 15.3608 Hz
# EPOCH 34 TRAIN) loss: 66.0597, acc: 0.8121, fr: 15.9050 Hz
# EPOCH 34 VALID) loss: 66.9706, acc: 0.6875, fr: 16.3623 Hz
# EPOCH 35 TRAIN) loss: 66.2467, acc: 0.7856, fr: 16.9959 Hz
# EPOCH 35 VALID) loss: 65.9225, acc: 0.7617, fr: 17.3798 Hz
# EPOCH 36 TRAIN) loss: 65.8844, acc: 0.7947, fr: 18.0039 Hz
# EPOCH 36 VALID) loss: 65.5126, acc: 0.9180, fr: 18.3975 Hz
# EPOCH 37 TRAIN) loss: 65.6428, acc: 0.8459, fr: 19.0004 Hz
# EPOCH 37 VALID) loss: 65.0813, acc: 0.8242, fr: 19.3639 Hz
# EPOCH 38 TRAIN) loss: 65.2870, acc: 0.8424, fr: 20.0218 Hz
# EPOCH 38 VALID) loss: 65.1111, acc: 0.7578, fr: 20.4195 Hz
# EPOCH 39 TRAIN) loss: 65.4841, acc: 0.8129, fr: 21.0257 Hz
# EPOCH 39 VALID) loss: 65.3377, acc: 0.7656, fr: 21.3328 Hz
# EPOCH 40 TRAIN) loss: 65.0933, acc: 0.8247, fr: 21.8107 Hz
# EPOCH 40 VALID) loss: 64.9598, acc: 0.7852, fr: 22.0252 Hz
# EPOCH 41 TRAIN) loss: 65.1161, acc: 0.8134, fr: 22.4004 Hz
# EPOCH 9 TRAIN) loss: 65.1245, acc: 0.9175, fr: 2.4270 Hz
# EPOCH 9 VALID) loss: 65.0154, acc: 0.9219, fr: 2.6076 Hz
# EPOCH 10 TRAIN) loss: 64.2932, acc: 0.9557, fr: 2.7470 Hz
# EPOCH 10 VALID) loss: 63.9306, acc: 0.9492, fr: 2.9297 Hz
# EPOCH 11 TRAIN) loss: 63.4797, acc: 0.9696, fr: 3.0302 Hz
# EPOCH 11 VALID) loss: 63.3884, acc: 0.9531, fr: 3.1854 Hz
# EPOCH 12 TRAIN) loss: 62.9103, acc: 0.9696, fr: 3.2824 Hz
# EPOCH 12 VALID) loss: 62.5636, acc: 0.9688, fr: 3.4295 Hz
# EPOCH 13 TRAIN) loss: 62.4080, acc: 0.9740, fr: 3.5124 Hz
# EPOCH 13 VALID) loss: 62.2635, acc: 0.9531, fr: 3.6884 Hz
# EPOCH 14 TRAIN) loss: 61.9005, acc: 0.9783, fr: 3.7982 Hz
# EPOCH 14 VALID) loss: 61.7719, acc: 0.9648, fr: 3.9543 Hz
# EPOCH 15 TRAIN) loss: 61.5073, acc: 0.9800, fr: 4.0836 Hz
# EPOCH 15 VALID) loss: 61.3882, acc: 0.9688, fr: 4.2515 Hz
# EPOCH 16 TRAIN) loss: 61.3263, acc: 0.9796, fr: 4.3439 Hz
# EPOCH 16 VALID) loss: 61.2745, acc: 0.9648, fr: 4.5101 Hz
# EPOCH 17 TRAIN) loss: 61.4806, acc: 0.9779, fr: 4.5893 Hz
# EPOCH 17 VALID) loss: 60.8667, acc: 0.9648, fr: 4.6939 Hz
# EPOCH 18 TRAIN) loss: 61.2526, acc: 0.9844, fr: 4.7709 Hz
# EPOCH 18 VALID) loss: 61.7054, acc: 0.9688, fr: 4.8961 Hz
# EPOCH 19 TRAIN) loss: 61.1026, acc: 0.9852, fr: 4.9931 Hz
# EPOCH 19 VALID) loss: 61.1622, acc: 0.9766, fr: 5.1579 Hz
# EPOCH 20 TRAIN) loss: 61.3559, acc: 0.9848, fr: 5.2455 Hz
# EPOCH 20 VALID) loss: 61.2625, acc: 0.9922, fr: 5.4343 Hz
# EPOCH 21 TRAIN) loss: 61.4188, acc: 0.9839, fr: 5.5463 Hz
# EPOCH 21 VALID) loss: 61.5667, acc: 0.9883, fr: 5.7113 Hz
# EPOCH 22 TRAIN) loss: 61.2094, acc: 0.9805, fr: 5.8115 Hz
# EPOCH 22 VALID) loss: 62.0770, acc: 0.9766, fr: 6.0201 Hz
# EPOCH 23 TRAIN) loss: 60.7627, acc: 0.9805, fr: 6.0969 Hz
# EPOCH 23 VALID) loss: 60.9596, acc: 0.9805, fr: 6.2672 Hz
# EPOCH 24 TRAIN) loss: 60.3857, acc: 0.9835, fr: 6.3828 Hz
# EPOCH 24 VALID) loss: 61.4698, acc: 0.9688, fr: 6.5884 Hz
# EPOCH 25 TRAIN) loss: 60.0559, acc: 0.9835, fr: 6.6929 Hz
# EPOCH 25 VALID) loss: 60.8400, acc: 0.9844, fr: 6.8921 Hz
# EPOCH 26 TRAIN) loss: 59.8612, acc: 0.9839, fr: 7.0109 Hz
# EPOCH 26 VALID) loss: 59.7580, acc: 0.9961, fr: 7.2379 Hz
# EPOCH 27 TRAIN) loss: 59.6174, acc: 0.9865, fr: 7.3780 Hz
# EPOCH 27 VALID) loss: 60.3145, acc: 0.9961, fr: 7.5951 Hz
# EPOCH 28 TRAIN) loss: 59.5736, acc: 0.9831, fr: 7.7793 Hz
# EPOCH 28 VALID) loss: 60.7454, acc: 0.9766, fr: 8.0013 Hz
# EPOCH 29 TRAIN) loss: 59.6350, acc: 0.9792, fr: 8.1282 Hz
# EPOCH 29 VALID) loss: 60.0789, acc: 0.9766, fr: 8.3159 Hz
# EPOCH 30 TRAIN) loss: 59.1118, acc: 0.9809, fr: 8.4887 Hz
# EPOCH 30 VALID) loss: 60.3100, acc: 0.9805, fr: 8.7983 Hz
# EPOCH 31 TRAIN) loss: 59.8818, acc: 0.9753, fr: 8.9615 Hz
# EPOCH 31 VALID) loss: 60.3494, acc: 0.9648, fr: 9.1902 Hz
# EPOCH 32 TRAIN) loss: 60.1620, acc: 0.9718, fr: 9.3777 Hz
# EPOCH 32 VALID) loss: 61.4435, acc: 0.9492, fr: 9.6395 Hz
# EPOCH 33 TRAIN) loss: 60.7006, acc: 0.9640, fr: 9.8135 Hz
# EPOCH 33 VALID) loss: 61.1725, acc: 0.9414, fr: 9.9670 Hz
# EPOCH 34 TRAIN) loss: 60.7694, acc: 0.9627, fr: 10.1388 Hz
# EPOCH 34 VALID) loss: 61.5598, acc: 0.9297, fr: 10.3280 Hz
# EPOCH 35 TRAIN) loss: 60.9278, acc: 0.9544, fr: 10.5484 Hz
# EPOCH 35 VALID) loss: 62.1093, acc: 0.9297, fr: 10.8286 Hz
# EPOCH 36 TRAIN) loss: 61.1843, acc: 0.9523, fr: 11.0781 Hz
# EPOCH 36 VALID) loss: 61.9639, acc: 0.9336, fr: 11.4699 Hz
# EPOCH 37 TRAIN) loss: 61.9160, acc: 0.9423, fr: 11.6617 Hz
# EPOCH 37 VALID) loss: 62.5886, acc: 0.9570, fr: 12.1145 Hz
# EPOCH 38 TRAIN) loss: 62.5720, acc: 0.9379, fr: 12.2614 Hz
# EPOCH 38 VALID) loss: 63.9938, acc: 0.9297, fr: 12.6442 Hz
# EPOCH 39 TRAIN) loss: 63.3782, acc: 0.9249, fr: 12.8461 Hz
# EPOCH 39 VALID) loss: 64.5141, acc: 0.8672, fr: 13.2859 Hz
# EPOCH 40 TRAIN) loss: 63.5673, acc: 0.9201, fr: 13.4567 Hz
# EPOCH 40 VALID) loss: 64.4928, acc: 0.8672, fr: 13.9716 Hz
# EPOCH 41 TRAIN) loss: 64.1856, acc: 0.8915, fr: 14.2094 Hz
# EPOCH 41 VALID) loss: 64.7635, acc: 0.8477, fr: 14.7327 Hz
# EPOCH 42 TRAIN) loss: 64.6379, acc: 0.8819, fr: 15.0155 Hz
# EPOCH 42 VALID) loss: 65.6346, acc: 0.8047, fr: 15.5650 Hz
# EPOCH 43 TRAIN) loss: 65.2803, acc: 0.8746, fr: 15.8570 Hz
# EPOCH 11 TRAIN) loss: 65.9503, acc: 0.8216, fr: 4.7058 Hz
# EPOCH 11 VALID) loss: 66.1021, acc: 0.7500, fr: 4.9027 Hz
# EPOCH 12 TRAIN) loss: 65.6045, acc: 0.7847, fr: 4.9821 Hz
# EPOCH 12 VALID) loss: 65.7295, acc: 0.7578, fr: 5.2411 Hz
# EPOCH 13 TRAIN) loss: 65.3265, acc: 0.8082, fr: 5.3595 Hz
# EPOCH 13 VALID) loss: 65.7407, acc: 0.7422, fr: 5.6149 Hz
# EPOCH 14 TRAIN) loss: 65.0796, acc: 0.8086, fr: 5.7186 Hz
# EPOCH 14 VALID) loss: 65.5163, acc: 0.7891, fr: 5.9445 Hz
# EPOCH 15 TRAIN) loss: 65.0090, acc: 0.8242, fr: 6.0415 Hz
# EPOCH 15 VALID) loss: 65.4546, acc: 0.8086, fr: 6.2828 Hz
# EPOCH 16 TRAIN) loss: 65.0344, acc: 0.8307, fr: 6.3798 Hz
# EPOCH 16 VALID) loss: 65.4760, acc: 0.7734, fr: 6.6530 Hz
# EPOCH 17 TRAIN) loss: 65.0013, acc: 0.8329, fr: 6.7429 Hz
# EPOCH 17 VALID) loss: 65.3961, acc: 0.7930, fr: 7.0164 Hz
# EPOCH 18 TRAIN) loss: 65.0238, acc: 0.8368, fr: 7.0790 Hz
# EPOCH 18 VALID) loss: 65.6045, acc: 0.8008, fr: 7.2894 Hz
# EPOCH 19 TRAIN) loss: 64.9782, acc: 0.8329, fr: 7.3570 Hz
# EPOCH 19 VALID) loss: 65.3149, acc: 0.8008, fr: 7.5584 Hz
# EPOCH 20 TRAIN) loss: 65.0991, acc: 0.8273, fr: 7.5851 Hz
# EPOCH 20 VALID) loss: 65.4045, acc: 0.7891, fr: 7.7420 Hz
# EPOCH 21 TRAIN) loss: 65.0242, acc: 0.8281, fr: 7.7689 Hz
# EPOCH 21 VALID) loss: 65.6089, acc: 0.7734, fr: 7.9196 Hz
# EPOCH 22 TRAIN) loss: 65.0221, acc: 0.8338, fr: 7.9384 Hz
# EPOCH 22 VALID) loss: 65.4548, acc: 0.7773, fr: 8.0620 Hz
# EPOCH 23 TRAIN) loss: 65.2422, acc: 0.8320, fr: 8.0893 Hz
# EPOCH 23 VALID) loss: 65.5885, acc: 0.7773, fr: 8.2321 Hz
# EPOCH 24 TRAIN) loss: 65.1571, acc: 0.8316, fr: 8.2435 Hz
# EPOCH 24 VALID) loss: 65.4705, acc: 0.7812, fr: 8.3904 Hz
# EPOCH 25 TRAIN) loss: 65.2092, acc: 0.8273, fr: 8.3866 Hz
# EPOCH 25 VALID) loss: 65.6792, acc: 0.7773, fr: 8.5336 Hz
# EPOCH 26 TRAIN) loss: 65.2549, acc: 0.8264, fr: 8.5426 Hz
# EPOCH 26 VALID) loss: 65.7536, acc: 0.7656, fr: 8.6961 Hz
# EPOCH 27 TRAIN) loss: 65.2819, acc: 0.8194, fr: 8.7178 Hz
# EPOCH 27 VALID) loss: 65.9742, acc: 0.7734, fr: 8.8634 Hz
# EPOCH 28 TRAIN) loss: 65.3191, acc: 0.8129, fr: 8.8946 Hz
# EPOCH 28 VALID) loss: 66.0103, acc: 0.7539, fr: 9.0308 Hz
# EPOCH 29 TRAIN) loss: 65.3001, acc: 0.8108, fr: 9.0713 Hz
# EPOCH 29 VALID) loss: 65.8676, acc: 0.7656, fr: 9.2413 Hz
# EPOCH 30 TRAIN) loss: 65.3948, acc: 0.8160, fr: 9.2626 Hz
# EPOCH 30 VALID) loss: 65.7950, acc: 0.7617, fr: 9.4416 Hz
# EPOCH 31 TRAIN) loss: 65.3444, acc: 0.8138, fr: 9.4613 Hz
# EPOCH 31 VALID) loss: 65.9000, acc: 0.7578, fr: 9.6528 Hz
# EPOCH 32 TRAIN) loss: 65.4061, acc: 0.8138, fr: 9.6845 Hz
# EPOCH 32 VALID) loss: 66.0455, acc: 0.7656, fr: 9.9247 Hz
# EPOCH 33 TRAIN) loss: 65.4489, acc: 0.8160, fr: 9.9079 Hz
# EPOCH 33 VALID) loss: 65.7995, acc: 0.7773, fr: 10.0902 Hz
# EPOCH 34 TRAIN) loss: 65.4109, acc: 0.8082, fr: 10.1326 Hz
# EPOCH 34 VALID) loss: 65.7749, acc: 0.7891, fr: 10.3562 Hz
# EPOCH 35 TRAIN) loss: 65.4846, acc: 0.8112, fr: 10.3804 Hz
# EPOCH 35 VALID) loss: 65.7473, acc: 0.8164, fr: 10.5952 Hz
# EPOCH 36 TRAIN) loss: 65.4395, acc: 0.8203, fr: 10.6162 Hz
# EPOCH 36 VALID) loss: 65.7264, acc: 0.8164, fr: 10.8303 Hz
# EPOCH 37 TRAIN) loss: 65.4961, acc: 0.8125, fr: 10.8582 Hz
# EPOCH 37 VALID) loss: 65.4928, acc: 0.8164, fr: 11.0380 Hz
# EPOCH 38 TRAIN) loss: 65.4761, acc: 0.8129, fr: 11.1020 Hz
# EPOCH 38 VALID) loss: 65.7124, acc: 0.8359, fr: 11.2648 Hz
# EPOCH 39 TRAIN) loss: 65.4551, acc: 0.8220, fr: 11.3250 Hz
# EPOCH 39 VALID) loss: 65.7133, acc: 0.8125, fr: 11.5053 Hz
# EPOCH 40 TRAIN) loss: 65.4808, acc: 0.8151, fr: 11.5771 Hz
# EPOCH 40 VALID) loss: 65.5271, acc: 0.8320, fr: 11.7355 Hz
# EPOCH 41 TRAIN) loss: 65.4426, acc: 0.8177, fr: 11.8004 Hz
# EPOCH 41 VALID) loss: 65.8724, acc: 0.7852, fr: 11.9633 Hz
# EPOCH 42 TRAIN) loss: 65.4051, acc: 0.8077, fr: 12.0011 Hz
# EPOCH 42 VALID) loss: 66.0745, acc: 0.7734, fr: 12.1841 Hz
# EPOCH 43 TRAIN) loss: 65.4250, acc: 0.8108, fr: 12.2652 Hz
# EPOCH 43 VALID) loss: 66.0278, acc: 0.7656, fr: 12.4330 Hz
# EPOCH 44 TRAIN) loss: 65.3542, acc: 0.8095, fr: 12.5215 Hz
# EPOCH 44 VALID) loss: 65.7497, acc: 0.7500, fr: 12.6703 Hz
# EPOCH 47 TRAIN) loss: 65.7942, acc: 0.8446, fr: 18.0882 Hz
# EPOCH 47 VALID) loss: 66.1400, acc: 0.7969, fr: 18.3166 Hz
# EPOCH 48 TRAIN) loss: 65.6508, acc: 0.8481, fr: 18.5999 Hz
# EPOCH 48 VALID) loss: 66.0298, acc: 0.7930, fr: 18.8287 Hz
# EPOCH 49 TRAIN) loss: 65.5715, acc: 0.8429, fr: 19.0842 Hz
# EPOCH 49 VALID) loss: 66.0393, acc: 0.8242, fr: 19.4030 Hz
# num_trial= 6
# data generated.
# (10, 256, 500, 40)
# (10, 256, 500)
# (10, 256, 500, 2)
# compile done.
# EPOCH 0 TRAIN) loss: 69.2886, acc: 0.5330, fr: 0.4876 Hz
# EPOCH 0 VALID) loss: 69.2908, acc: 0.5195, fr: 0.5377 Hz
# EPOCH 1 TRAIN) loss: 69.2774, acc: 0.5373, fr: 0.5874 Hz
# EPOCH 1 VALID) loss: 69.3021, acc: 0.4961, fr: 0.6560 Hz
# EPOCH 2 TRAIN) loss: 69.3020, acc: 0.5156, fr: 0.7718 Hz
# EPOCH 2 VALID) loss: 69.2874, acc: 0.4961, fr: 0.8778 Hz
# EPOCH 3 TRAIN) loss: 69.2961, acc: 0.4861, fr: 1.1199 Hz
# EPOCH 3 VALID) loss: 69.2794, acc: 0.4922, fr: 1.3366 Hz
# EPOCH 4 TRAIN) loss: 69.2350, acc: 0.5412, fr: 1.7024 Hz
# EPOCH 4 VALID) loss: 69.1833, acc: 0.5586, fr: 1.9445 Hz
# EPOCH 5 TRAIN) loss: 69.0544, acc: 0.5712, fr: 2.1382 Hz
# EPOCH 5 VALID) loss: 68.9348, acc: 0.5469, fr: 2.3030 Hz
# EPOCH 6 TRAIN) loss: 68.6750, acc: 0.5911, fr: 2.4848 Hz
# EPOCH 6 VALID) loss: 68.4394, acc: 0.5977, fr: 2.6516 Hz
# EPOCH 7 TRAIN) loss: 67.8724, acc: 0.7161, fr: 2.9605 Hz
# EPOCH 7 VALID) loss: 67.4110, acc: 0.8086, fr: 3.2359 Hz
# EPOCH 8 TRAIN) loss: 66.7233, acc: 0.8984, fr: 3.5861 Hz
# EPOCH 8 VALID) loss: 66.3821, acc: 0.9414, fr: 3.8884 Hz
# EPOCH 9 TRAIN) loss: 65.6433, acc: 0.9527, fr: 4.2369 Hz
# EPOCH 9 VALID) loss: 65.1088, acc: 0.9727, fr: 4.5123 Hz
# EPOCH 10 TRAIN) loss: 64.5953, acc: 0.9766, fr: 4.7915 Hz
# EPOCH 10 VALID) loss: 64.1457, acc: 0.9805, fr: 4.9386 Hz
# EPOCH 11 TRAIN) loss: 63.8418, acc: 0.9796, fr: 5.0911 Hz
# EPOCH 11 VALID) loss: 63.4127, acc: 0.9844, fr: 5.0977 Hz
# EPOCH 12 TRAIN) loss: 63.2579, acc: 0.9800, fr: 5.2210 Hz
# EPOCH 12 VALID) loss: 62.7336, acc: 0.9727, fr: 5.2461 Hz
# EPOCH 13 TRAIN) loss: 62.7236, acc: 0.9805, fr: 5.4080 Hz
# EPOCH 13 VALID) loss: 62.9320, acc: 0.9844, fr: 5.4570 Hz
# EPOCH 14 TRAIN) loss: 62.5686, acc: 0.9839, fr: 5.6291 Hz
# EPOCH 14 VALID) loss: 62.4531, acc: 0.9883, fr: 5.6773 Hz
# EPOCH 15 TRAIN) loss: 62.4067, acc: 0.9809, fr: 5.8127 Hz
# EPOCH 15 VALID) loss: 61.7704, acc: 0.9805, fr: 5.8104 Hz
# EPOCH 16 TRAIN) loss: 62.0132, acc: 0.9818, fr: 5.9382 Hz
# EPOCH 16 VALID) loss: 61.6618, acc: 0.9844, fr: 5.9258 Hz
# EPOCH 17 TRAIN) loss: 61.8118, acc: 0.9835, fr: 6.0729 Hz
# EPOCH 17 VALID) loss: 61.3697, acc: 0.9883, fr: 6.0967 Hz
# EPOCH 18 TRAIN) loss: 61.4390, acc: 0.9918, fr: 6.2245 Hz
# EPOCH 18 VALID) loss: 60.3311, acc: 0.9961, fr: 6.2490 Hz
# EPOCH 19 TRAIN) loss: 61.3630, acc: 0.9865, fr: 6.4036 Hz
# EPOCH 19 VALID) loss: 61.0869, acc: 0.9844, fr: 6.4410 Hz
# EPOCH 20 TRAIN) loss: 61.1334, acc: 0.9870, fr: 6.5827 Hz
# EPOCH 20 VALID) loss: 60.7185, acc: 0.9922, fr: 6.6645 Hz
# EPOCH 21 TRAIN) loss: 61.0205, acc: 0.9822, fr: 6.7582 Hz
# EPOCH 21 VALID) loss: 61.1048, acc: 0.9844, fr: 6.8300 Hz
# EPOCH 22 TRAIN) loss: 60.5825, acc: 0.9878, fr: 6.9367 Hz
# EPOCH 22 VALID) loss: 60.9370, acc: 0.9922, fr: 6.9838 Hz
# EPOCH 23 TRAIN) loss: 60.3696, acc: 0.9800, fr: 7.1127 Hz
# EPOCH 23 VALID) loss: 60.0404, acc: 0.9883, fr: 7.1891 Hz
# EPOCH 24 TRAIN) loss: 60.2625, acc: 0.9787, fr: 7.3082 Hz
# EPOCH 24 VALID) loss: 59.9518, acc: 0.9883, fr: 7.4097 Hz
# EPOCH 25 TRAIN) loss: 60.2612, acc: 0.9779, fr: 7.5247 Hz
# EPOCH 25 VALID) loss: 60.3486, acc: 0.9961, fr: 7.5870 Hz
# EPOCH 26 TRAIN) loss: 59.9184, acc: 0.9818, fr: 7.7069 Hz
# EPOCH 26 VALID) loss: 60.1962, acc: 0.9922, fr: 7.7699 Hz
# EPOCH 27 TRAIN) loss: 60.1570, acc: 0.9831, fr: 7.9158 Hz
# EPOCH 27 VALID) loss: 60.4019, acc: 0.9883, fr: 7.9745 Hz
# EPOCH 28 TRAIN) loss: 60.1377, acc: 0.9813, fr: 8.1196 Hz
# EPOCH 28 VALID) loss: 60.2768, acc: 0.9922, fr: 8.2220 Hz
# EPOCH 29 TRAIN) loss: 60.3036, acc: 0.9757, fr: 8.3459 Hz
# EPOCH 29 VALID) loss: 60.3719, acc: 0.9805, fr: 8.4463 Hz
# EPOCH 30 TRAIN) loss: 60.5063, acc: 0.9783, fr: 8.5690 Hz
# EPOCH 30 VALID) loss: 60.5355, acc: 0.9844, fr: 8.7154 Hz
# EPOCH 31 TRAIN) loss: 60.6729, acc: 0.9670, fr: 8.7958 Hz
# EPOCH 16 TRAIN) loss: 63.5589, acc: 0.9770, fr: 6.7341 Hz
# EPOCH 16 VALID) loss: 62.1359, acc: 0.9883, fr: 6.9751 Hz
# EPOCH 17 TRAIN) loss: 63.1582, acc: 0.9757, fr: 7.0794 Hz
# EPOCH 17 VALID) loss: 62.3682, acc: 0.9766, fr: 7.2916 Hz
# EPOCH 18 TRAIN) loss: 62.7604, acc: 0.9731, fr: 7.3859 Hz
# EPOCH 18 VALID) loss: 61.7068, acc: 0.9922, fr: 7.6284 Hz
# EPOCH 19 TRAIN) loss: 62.5410, acc: 0.9735, fr: 7.7304 Hz
# EPOCH 19 VALID) loss: 61.6412, acc: 0.9883, fr: 7.9116 Hz
# EPOCH 20 TRAIN) loss: 62.1787, acc: 0.9792, fr: 8.0237 Hz
# EPOCH 20 VALID) loss: 61.3062, acc: 0.9766, fr: 8.2279 Hz
# EPOCH 21 TRAIN) loss: 61.8789, acc: 0.9800, fr: 8.3252 Hz
# EPOCH 21 VALID) loss: 61.0319, acc: 0.9766, fr: 8.4977 Hz
# EPOCH 22 TRAIN) loss: 61.6528, acc: 0.9826, fr: 8.6317 Hz
# EPOCH 22 VALID) loss: 60.6659, acc: 0.9844, fr: 8.8188 Hz
# EPOCH 23 TRAIN) loss: 61.3708, acc: 0.9792, fr: 8.9746 Hz
# EPOCH 23 VALID) loss: 60.6190, acc: 0.9766, fr: 9.2247 Hz
# EPOCH 24 TRAIN) loss: 61.3305, acc: 0.9714, fr: 9.3697 Hz
# EPOCH 24 VALID) loss: 60.2576, acc: 0.9766, fr: 9.6447 Hz
# EPOCH 25 TRAIN) loss: 61.3163, acc: 0.9727, fr: 9.8523 Hz
# EPOCH 25 VALID) loss: 60.9521, acc: 0.9766, fr: 10.2397 Hz
# EPOCH 26 TRAIN) loss: 61.3760, acc: 0.9635, fr: 10.4267 Hz
# EPOCH 26 VALID) loss: 60.3563, acc: 0.9648, fr: 10.7870 Hz
# EPOCH 27 TRAIN) loss: 61.4220, acc: 0.9583, fr: 11.0151 Hz
# EPOCH 27 VALID) loss: 60.2924, acc: 0.9570, fr: 11.4729 Hz
# EPOCH 28 TRAIN) loss: 61.5072, acc: 0.9440, fr: 11.6853 Hz
# EPOCH 28 VALID) loss: 60.1041, acc: 0.9805, fr: 12.1805 Hz
# EPOCH 29 TRAIN) loss: 61.4897, acc: 0.9405, fr: 12.4313 Hz
# EPOCH 29 VALID) loss: 60.9752, acc: 0.9375, fr: 12.9149 Hz
# EPOCH 30 TRAIN) loss: 61.5627, acc: 0.9123, fr: 13.1014 Hz
# EPOCH 30 VALID) loss: 60.9826, acc: 0.9180, fr: 13.5850 Hz
# EPOCH 31 TRAIN) loss: 61.6140, acc: 0.8932, fr: 13.7707 Hz
# EPOCH 31 VALID) loss: 60.8065, acc: 0.9219, fr: 14.2311 Hz
# EPOCH 32 TRAIN) loss: 61.5069, acc: 0.8945, fr: 14.4021 Hz
# EPOCH 32 VALID) loss: 60.7278, acc: 0.9531, fr: 14.8267 Hz
# EPOCH 33 TRAIN) loss: 61.5927, acc: 0.8806, fr: 14.9883 Hz
# EPOCH 33 VALID) loss: 60.2263, acc: 0.9688, fr: 15.3708 Hz
# EPOCH 34 TRAIN) loss: 61.3699, acc: 0.8963, fr: 15.5795 Hz
# EPOCH 34 VALID) loss: 60.9622, acc: 0.9102, fr: 16.1308 Hz
# EPOCH 35 TRAIN) loss: 62.5923, acc: 0.8950, fr: 16.4014 Hz
# EPOCH 35 VALID) loss: 62.6574, acc: 0.8320, fr: 16.9796 Hz
# EPOCH 36 TRAIN) loss: 63.2373, acc: 0.9162, fr: 17.1851 Hz
# EPOCH 36 VALID) loss: 62.6970, acc: 0.8867, fr: 17.6700 Hz
# EPOCH 37 TRAIN) loss: 63.5107, acc: 0.9071, fr: 17.9866 Hz
# EPOCH 37 VALID) loss: 62.7883, acc: 0.8750, fr: 18.5530 Hz
# EPOCH 38 TRAIN) loss: 63.4969, acc: 0.8963, fr: 18.7987 Hz
# EPOCH 38 VALID) loss: 63.4999, acc: 0.8242, fr: 19.2698 Hz
# EPOCH 39 TRAIN) loss: 63.8828, acc: 0.8763, fr: 19.4214 Hz
# EPOCH 39 VALID) loss: 63.1842, acc: 0.8203, fr: 19.8865 Hz
# EPOCH 40 TRAIN) loss: 64.2999, acc: 0.8576, fr: 20.0032 Hz
# EPOCH 40 VALID) loss: 64.3093, acc: 0.7695, fr: 20.4852 Hz
# EPOCH 41 TRAIN) loss: 64.4352, acc: 0.8637, fr: 20.6942 Hz
# EPOCH 41 VALID) loss: 64.1713, acc: 0.7812, fr: 21.3448 Hz
# EPOCH 42 TRAIN) loss: 64.4648, acc: 0.8533, fr: 21.5034 Hz
# EPOCH 42 VALID) loss: 63.8740, acc: 0.8398, fr: 22.1395 Hz
# EPOCH 43 TRAIN) loss: 64.8798, acc: 0.8433, fr: 22.3508 Hz
# EPOCH 43 VALID) loss: 64.9493, acc: 0.6992, fr: 23.0077 Hz
# EPOCH 44 TRAIN) loss: 65.3043, acc: 0.8377, fr: 23.1257 Hz
# EPOCH 44 VALID) loss: 64.8466, acc: 0.7109, fr: 23.7591 Hz
# EPOCH 45 TRAIN) loss: 65.2450, acc: 0.8299, fr: 23.8073 Hz
# EPOCH 45 VALID) loss: 64.9151, acc: 0.7383, fr: 24.3870 Hz
# EPOCH 46 TRAIN) loss: 65.1947, acc: 0.8121, fr: 24.4523 Hz
# EPOCH 46 VALID) loss: 65.2599, acc: 0.6836, fr: 24.9255 Hz
# EPOCH 47 TRAIN) loss: 65.5787, acc: 0.7760, fr: 24.9465 Hz
# EPOCH 47 VALID) loss: 66.2050, acc: 0.6211, fr: 25.3712 Hz
# EPOCH 48 TRAIN) loss: 66.0059, acc: 0.7400, fr: 25.3539 Hz
# EPOCH 48 VALID) loss: 66.1309, acc: 0.6055, fr: 25.7708 Hz
# EPOCH 49 TRAIN) loss: 66.2520, acc: 0.7240, fr: 25.5758 Hz
# EPOCH 49 VALID) loss: 67.0989, acc: 0.5938, fr: 25.8651 Hz
# num_trial= 8
# data generated.
# (10, 256, 500, 40)
# (10, 256, 500)
# (10, 256, 500, 2)
# compile done.
# EPOCH 0 TRAIN) loss: 69.3157, acc: 0.5174, fr: 0.4504 Hz
# EPOCH 0 VALID) loss: 69.3095, acc: 0.5078, fr: 0.4582 Hz
# EPOCH 1 TRAIN) loss: 69.3081, acc: 0.5295, fr: 0.5027 Hz
# EPOCH 1 VALID) loss: 69.3037, acc: 0.5117, fr: 0.5659 Hz
# EPOCH 2 TRAIN) loss: 69.2884, acc: 0.5269, fr: 0.6549 Hz
# EPOCH 2 VALID) loss: 69.2518, acc: 0.5234, fr: 0.7662 Hz
# EPOCH 3 TRAIN) loss: 69.2479, acc: 0.5226, fr: 0.8669 Hz
# EPOCH 3 VALID) loss: 69.1936, acc: 0.5156, fr: 0.9980 Hz
# EPOCH 4 TRAIN) loss: 69.1204, acc: 0.5182, fr: 1.1133 Hz
# EPOCH 4 VALID) loss: 68.9685, acc: 0.5391, fr: 1.2841 Hz
# EPOCH 5 TRAIN) loss: 68.7864, acc: 0.5438, fr: 1.4235 Hz
# EPOCH 5 VALID) loss: 68.4731, acc: 0.5781, fr: 1.6341 Hz
# EPOCH 6 TRAIN) loss: 68.1002, acc: 0.6042, fr: 1.8190 Hz
# EPOCH 6 VALID) loss: 67.3894, acc: 0.6758, fr: 2.0852 Hz
# EPOCH 7 TRAIN) loss: 67.0511, acc: 0.7148, fr: 2.3324 Hz
# EPOCH 7 VALID) loss: 66.1783, acc: 0.8125, fr: 2.6916 Hz
# EPOCH 8 TRAIN) loss: 65.9494, acc: 0.8498, fr: 3.0015 Hz
# EPOCH 8 VALID) loss: 65.3610, acc: 0.9297, fr: 3.4011 Hz
# EPOCH 9 TRAIN) loss: 65.6387, acc: 0.9431, fr: 3.6430 Hz
# EPOCH 9 VALID) loss: 65.4923, acc: 0.9688, fr: 3.9203 Hz
# EPOCH 10 TRAIN) loss: 65.6345, acc: 0.9553, fr: 4.0564 Hz
# EPOCH 10 VALID) loss: 65.3134, acc: 0.9453, fr: 4.1595 Hz
# EPOCH 11 TRAIN) loss: 65.1046, acc: 0.9253, fr: 4.1853 Hz
# EPOCH 11 VALID) loss: 64.5562, acc: 0.9648, fr: 4.1501 Hz
# EPOCH 12 TRAIN) loss: 64.6714, acc: 0.9275, fr: 4.1356 Hz
# EPOCH 12 VALID) loss: 64.4092, acc: 0.9531, fr: 4.1234 Hz
# EPOCH 13 TRAIN) loss: 64.2796, acc: 0.9271, fr: 4.1772 Hz
# EPOCH 13 VALID) loss: 63.9430, acc: 0.9492, fr: 4.2758 Hz
# EPOCH 14 TRAIN) loss: 64.0342, acc: 0.9362, fr: 4.3974 Hz
# EPOCH 14 VALID) loss: 63.8502, acc: 0.9453, fr: 4.5496 Hz
# EPOCH 15 TRAIN) loss: 63.8318, acc: 0.9444, fr: 4.6999 Hz
# EPOCH 15 VALID) loss: 63.5024, acc: 0.9531, fr: 4.8820 Hz
# EPOCH 16 TRAIN) loss: 63.4412, acc: 0.9418, fr: 5.0607 Hz
# EPOCH 16 VALID) loss: 63.0413, acc: 0.9570, fr: 5.2337 Hz
# EPOCH 17 TRAIN) loss: 63.0058, acc: 0.9431, fr: 5.4375 Hz
# EPOCH 17 VALID) loss: 62.9811, acc: 0.9414, fr: 5.6739 Hz
# EPOCH 18 TRAIN) loss: 62.5601, acc: 0.9384, fr: 5.8609 Hz
# EPOCH 18 VALID) loss: 62.7758, acc: 0.9492, fr: 6.0727 Hz
# EPOCH 19 TRAIN) loss: 62.0864, acc: 0.9427, fr: 6.3023 Hz
# EPOCH 19 VALID) loss: 62.4877, acc: 0.9336, fr: 6.5420 Hz
# EPOCH 20 TRAIN) loss: 62.2769, acc: 0.9440, fr: 6.8062 Hz
# EPOCH 20 VALID) loss: 62.5911, acc: 0.9492, fr: 7.0097 Hz
# EPOCH 21 TRAIN) loss: 61.7670, acc: 0.9440, fr: 7.2293 Hz
# EPOCH 21 VALID) loss: 62.0250, acc: 0.9453, fr: 7.4309 Hz
# EPOCH 22 TRAIN) loss: 61.8084, acc: 0.9358, fr: 7.6290 Hz
# EPOCH 22 VALID) loss: 61.6233, acc: 0.9648, fr: 7.9217 Hz
# EPOCH 23 TRAIN) loss: 61.7469, acc: 0.9327, fr: 8.1095 Hz
# EPOCH 23 VALID) loss: 62.7337, acc: 0.9180, fr: 8.3647 Hz
# EPOCH 24 TRAIN) loss: 61.9358, acc: 0.9336, fr: 8.6274 Hz
# EPOCH 24 VALID) loss: 62.2051, acc: 0.9375, fr: 8.8800 Hz
# EPOCH 25 TRAIN) loss: 62.0140, acc: 0.9262, fr: 9.1369 Hz
# EPOCH 25 VALID) loss: 62.7108, acc: 0.9570, fr: 9.4545 Hz
# EPOCH 26 TRAIN) loss: 62.0451, acc: 0.9210, fr: 9.7100 Hz
# EPOCH 26 VALID) loss: 62.3193, acc: 0.9453, fr: 9.9883 Hz
# EPOCH 27 TRAIN) loss: 62.2123, acc: 0.9141, fr: 10.3576 Hz
# EPOCH 27 VALID) loss: 62.7393, acc: 0.9336, fr: 10.7395 Hz
# EPOCH 28 TRAIN) loss: 62.4198, acc: 0.9145, fr: 11.0562 Hz
# EPOCH 28 VALID) loss: 63.0448, acc: 0.9375, fr: 11.4466 Hz
# EPOCH 29 TRAIN) loss: 62.9034, acc: 0.8863, fr: 11.8548 Hz
# EPOCH 29 VALID) loss: 63.8090, acc: 0.9180, fr: 12.3175 Hz
# EPOCH 30 TRAIN) loss: 63.4010, acc: 0.8698, fr: 12.7166 Hz
# EPOCH 30 VALID) loss: 63.3604, acc: 0.9102, fr: 13.1340 Hz
# EPOCH 31 TRAIN) loss: 63.7287, acc: 0.8511, fr: 13.5713 Hz
# EPOCH 31 VALID) loss: 63.7530, acc: 0.8750, fr: 14.1227 Hz
# EPOCH 32 TRAIN) loss: 64.3975, acc: 0.8342, fr: 14.6238 Hz
# EPOCH 32 VALID) loss: 64.1903, acc: 0.8008, fr: 15.2501 Hz
# EPOCH 33 TRAIN) loss: 64.6449, acc: 0.8186, fr: 15.7682 Hz
# EPOCH 33 VALID) loss: 64.9371, acc: 0.7852, fr: 16.4359 Hz
# EPOCH 34 TRAIN) loss: 64.8308, acc: 0.8481, fr: 16.9436 Hz
# EPOCH 34 VALID) loss: 64.8020, acc: 0.8359, fr: 17.5440 Hz
# EPOCH 35 TRAIN) loss: 65.3585, acc: 0.8234, fr: 18.0897 Hz
# EPOCH 35 VALID) loss: 65.3461, acc: 0.8125, fr: 18.8363 Hz
# EPOCH 36 TRAIN) loss: 65.4377, acc: 0.8164, fr: 19.2521 Hz
# EPOCH 36 VALID) loss: 65.6215, acc: 0.8516, fr: 19.8941 Hz
# EPOCH 37 TRAIN) loss: 65.5893, acc: 0.8168, fr: 20.2922 Hz
# EPOCH 37 VALID) loss: 65.8882, acc: 0.8398, fr: 20.9336 Hz
# EPOCH 38 TRAIN) loss: 65.8225, acc: 0.8164, fr: 21.2638 Hz
# EPOCH 38 VALID) loss: 66.2698, acc: 0.8359, fr: 21.7938 Hz
# EPOCH 39 TRAIN) loss: 65.9938, acc: 0.7882, fr: 22.0230 Hz
# EPOCH 39 VALID) loss: 66.5245, acc: 0.7930, fr: 22.4745 Hz
# EPOCH 40 TRAIN) loss: 66.0019, acc: 0.7717, fr: 22.6607 Hz
# EPOCH 40 VALID) loss: 66.8283, acc: 0.7891, fr: 23.0498 Hz
# EPOCH 41 TRAIN) loss: 66.1045, acc: 0.7778, fr: 23.2300 Hz
# EPOCH 41 VALID) loss: 66.8182, acc: 0.7500, fr: 23.5510 Hz
# EPOCH 42 TRAIN) loss: 66.2635, acc: 0.7483, fr: 23.7527 Hz
# EPOCH 42 VALID) loss: 66.9198, acc: 0.7305, fr: 24.0533 Hz
# EPOCH 43 TRAIN) loss: 66.2976, acc: 0.7322, fr: 24.2232 Hz
# EPOCH 43 VALID) loss: 67.2532, acc: 0.6797, fr: 24.5451 Hz
# EPOCH 44 TRAIN) loss: 66.8251, acc: 0.6931, fr: 24.7605 Hz
# EPOCH 44 VALID) loss: 67.5341, acc: 0.5859, fr: 25.1364 Hz
# EPOCH 45 TRAIN) loss: 67.2284, acc: 0.6727, fr: 25.4178 Hz
# EPOCH 45 VALID) loss: 67.5935, acc: 0.5547, fr: 25.8310 Hz
# EPOCH 46 TRAIN) loss: 67.6624, acc: 0.6454, fr: 26.0169 Hz
# EPOCH 46 VALID) loss: 68.0973, acc: 0.5312, fr: 26.6505 Hz
# EPOCH 47 TRAIN) loss: 68.3769, acc: 0.6302, fr: 26.8612 Hz
# EPOCH 47 VALID) loss: 68.0569, acc: 0.5312, fr: 27.3132 Hz
# EPOCH 48 TRAIN) loss: 68.5783, acc: 0.6411, fr: 27.4993 Hz
# EPOCH 48 VALID) loss: 67.4042, acc: 0.5703, fr: 27.8590 Hz
# EPOCH 49 TRAIN) loss: 68.6763, acc: 0.6463, fr: 27.9787 Hz
# EPOCH 49 VALID) loss: 66.1266, acc: 0.7891, fr: 28.6310 Hz
# num_trial= 9

# %%
last_acc
# Out:
# array([0.92578125, 0.8046875 , 0.828125  , 0.49609375, 0.6875    ,
#        0.75      , 0.82421875, 0.8515625 , 0.59375   , 0.7890625 ])

# %%
np.mean(last_acc)
# Out:
# 0.755078125
