# %%
import numpy as np
import matplotlib.pyplot as plt
import spikes4 as spk4
import snn_models

num_trial = 10
last_acc = np.zeros(num_trial)

np.random.seed(545)

for i in range(num_trial): 

    #%% parameters
    time_step = 1 # 1ms time resolution    

    lr = 0.002 # learning rate 0.005
    thr = 0.6 # v threshold
    tau_out = 3 # output decay time constant /// unit: ms
    kappa = np.exp(-time_step/tau_out) # output decay
    tau_mem = 20 # v decay time constant /// unit: ms
    alpha = np.exp(-time_step/tau_mem) # v decay
    beta = 0.2 # adaptation increment 
    tau_a = 200 # adaptation decay time constant /// unit: ms
    rho = np.exp(-time_step/(tau_a+1e-12)) # adaptation decay
    t_ref = 2 # refractory period /// unit: ms    

    decays = np.array([lr, thr, alpha, beta, kappa, rho, t_ref]) # save as a vector    

    #%% input data generation
    nb_inputs, nb_hidden, nb_outputs  = 40, 100, 2 # number of neurons
    batch_size = 256
    nb_batch = 10 # number of batches
    nb_data = batch_size*nb_batch # =256*10
    n_train = batch_size*(nb_batch-1) # =256*9
    n_test = batch_size # =256*1
    nb_steps = 500 # simulation duration (ms)
    dur_stim = 100 # stimulation duration (ms)    

    x = np.zeros((nb_batch,batch_size,nb_steps,40)) # input dta train
    y1hot = np.zeros((nb_batch,batch_size,nb_steps,2)) # target data (1hot encoding)
    y = np.zeros((nb_batch,batch_size,nb_steps,)) # target data (0 for left, 1 for right, 0.5 otherwise)    

    for batch_idx in range(nb_batch):
        for b in range(batch_size):
            y_data = 0.5*np.ones((nb_steps)) 
            y_data1hot = np.zeros((nb_steps, 2))
            cue_on = np.zeros((nb_steps),dtype=bool) # learning cue, True when learing cue is on.
            
            prob_noise = 1*(time_step/1000) #!!! noise has 1Hz spike frequency
            x_data = np.random.choice(2, size=(nb_steps,nb_inputs),p=[1-prob_noise,prob_noise])
            
            t_stim = np.random.randint(0,350) # stimuli given random time interval [0,350]ms
            t_learn = 400 # learning cue starts at 400ms
            prob_stim = 40*(time_step/1000) #!!! input has 40Hz spike frequency
            x_stim = np.random.choice(2, size=(dur_stim,int(nb_inputs/4)),p=[1-prob_stim,prob_stim]).astype(float)
            l_or_r = np.random.choice(2) # left or right?
            x_data[t_stim:t_stim+dur_stim, int(nb_inputs/4)*l_or_r:int(nb_inputs/4)*l_or_r+int(nb_inputs/4)] = x_stim
            
            x_learn = np.random.choice(2, size=(dur_stim,int(nb_inputs/4)),p=[1-prob_stim,prob_stim]).astype(float)
            x_data[t_learn:t_learn+dur_stim, int(nb_inputs/4)*2:int(nb_inputs/4)*2+int(nb_inputs/4)] = x_learn
            
            y_data1hot[t_learn:t_learn+dur_stim, l_or_r] = 1
            cue_on[t_learn:t_learn+dur_stim] = True
            y_data[t_learn:t_learn+dur_stim] = l_or_r    

            x[batch_idx,b] = x_data
            y[batch_idx,b] = y_data
            y1hot[batch_idx,b] = y_data1hot
    print('data generated.')
    stim = 2*y-1 # same as y, but -1 for left, 1 for right, and 0 otherwise    

    print(x.shape)
    print(y.shape)
    print(y1hot.shape)    

    #%% initialize weight
    weight_scale = 10*(1.0-alpha) #!!!
    w1 = np.random.normal(size=(nb_inputs,nb_hidden), loc=0.0, scale=weight_scale/np.sqrt(nb_inputs)) # input-->hidden
    w2 = np.random.normal(size=(nb_hidden,nb_outputs), loc=0.0, scale=weight_scale/np.sqrt(nb_hidden)) # hidden-->hidden
    #bias = np.random.normal(size=(nb_outputs), loc=0.0, scale=weight_scale/np.sqrt(nb_outputs)) # output bias
    bias = np.zeros(nb_outputs) # output bias
    B = np.random.normal(size=(nb_outputs,nb_hidden), loc=0.0, scale=weight_scale/np.sqrt(nb_outputs)) #!!! random e-prop    

    #%% recurrent weights (choose only one)
    ############### (1) random network ###############
    # wr = np.random.normal(size=(nb_hidden,nb_hidden), loc=0.0, scale=weight_scale/np.sqrt(nb_hidden)) # hidden-->output
    # np.fill_diagonal(wr,0) # no self connectivity    

    ############### (2) E/I network ###############
    import graph_analysis
    nb_e = int(nb_hidden*0.8)
    nb_i = nb_hidden - nb_e
    ind_fromi = np.zeros((nb_hidden,nb_hidden),dtype=bool)
    ind_fromi[nb_e:,:] = True # index of inhibitory neurons    

    wr, xy, cdens = graph_analysis.aij_distance2d([1000,1000], [250,150], nb_e, nb_i, np.array([[1,-1],[1,-1]]), cself=False, plot=False, randomseed=None)
    wr = wr.T
    wr *= 0.05 # scaling    

    plt.imshow(wr) # visualize initial weights    

    #%% compile (1st run numba is slow)
    x_tmp, y1hot_tmp, cue_on_tmp = x[0,:,:3,:].copy(),y1hot[0,:,:3,:].copy(),cue_on[:3].copy()
    loss, out_rec, dw1, dwr, dw2, dbias, v_rec, z_rec, a_rec = snn_models.lif_eprop(w1,wr,w2,bias,B,x_tmp, y1hot_tmp, cue_on_tmp,decays)
    print('compile done.')    

    #%% run train
    dw1_past = np.zeros((nb_inputs,nb_hidden))
    dw2_past = np.zeros((nb_hidden,nb_outputs))
    dwr_past = np.zeros((nb_hidden,nb_hidden))
    dbias_past = np.zeros((nb_outputs,))
    loss_train, fr_train, acc_train, spktr, wrs, atr, w1s, w2s, biases = [],[],[],[],[],[],[],[],[]
    loss_valid, fr_valid, acc_valid = [],[],[]
    n_epochs = 50

    # Adam
    m_t_w1 = np.zeros((nb_inputs,nb_hidden))
    m_t_w2 = np.zeros((nb_hidden,nb_outputs))
    m_t_wr = np.zeros((nb_hidden,nb_hidden))
    m_t_bias = np.zeros((nb_outputs,))

    v_t_w1 = np.zeros((nb_inputs,nb_hidden))
    v_t_w2 = np.zeros((nb_hidden,nb_outputs))
    v_t_wr = np.zeros((nb_hidden,nb_hidden))
    v_t_bias = np.zeros((nb_outputs,))

    b1 = 0.9
    b2 = 0.999
    alpha_lr = 0.002
    eps = 1e-9

    for epoch in range(n_epochs): # 100
        ######################### train #########################
        loss_batch,acc_batch,fr_batch = np.zeros((nb_batch-1,)), np.zeros((nb_batch-1,)), np.zeros((nb_batch-1,))
        for batch_idx in range(nb_batch-1): # batch_idx = 0
            x_batch,y1hot_batch,y_batch = x[batch_idx],y1hot[batch_idx],y[batch_idx]
            
            # Adam
            # m_t_w1 = b1 * m_t_w1 + (1 - b1) / (-lr) * np.mean(dw1, 0)
            # m_t_w2 = b1 * m_t_w2 + (1 - b1) / (-lr) * np.mean(dw2, 0)
            # m_t_wr = b1 * m_t_wr + (1 - b1) / (-lr) * np.mean(dwr, 0)
            # m_t_bias = b1 * m_t_bias + (1 - b1) / (-lr) * np.mean(dbias, 0)

            # v_t_w1 = b2 * v_t_w1 + (1 - b2) / (lr**2) * np.power(np.mean(dw1, 0), 2)
            # v_t_w2 = b2 * v_t_w2 + (1 - b2) / (lr**2) * np.power(np.mean(dw2, 0), 2)
            # v_t_wr = b2 * v_t_wr + (1 - b2) / (lr**2) * np.power(np.mean(dwr, 0), 2)
            # v_t_bias = b2 * v_t_bias + (1 - b2) / (lr**2) * np.power(np.mean(dbias, 0), 2)

            # t = (epoch + 1)

            # m_w1_corr = m_t_w1 / (1. - b1**t)
            # m_w2_corr = m_t_w2 / (1. - b1**t)
            # m_wr_corr = m_t_wr / (1. - b1**t)
            # m_bias_corr = m_t_bias / (1. - b1**t)

            # v_w1_corr = v_t_w1 / (1. - b2**t)
            # v_w2_corr = v_t_w2 / (1. - b2**t)
            # v_wr_corr = v_t_wr / (1. - b2**t)
            # v_bias_corr = v_t_bias / (1. - b2**t)

            # div_w1 = -alpha_lr * m_w1_corr / (np.sqrt(v_w1_corr) + eps * np.ones_like(v_w1_corr))
            # div_w2 = -alpha_lr * m_w2_corr / (np.sqrt(v_w2_corr) + eps * np.ones_like(v_w2_corr))
            # div_wr = -alpha_lr * m_wr_corr / (np.sqrt(v_wr_corr) + eps * np.ones_like(v_wr_corr))
            # div_bias = -alpha_lr * m_bias_corr / (np.sqrt(v_bias_corr) + eps * np.ones_like(v_bias_corr))

            # w1 += div_w1 # input-->hidden update
            # w2 += div_w2 # hidden-->hidden update
            # wr += div_wr # hidden-->output update
            # bias += div_bias # bias update

            # Momemtum
            loss, out_rec, dw1, dwr, dw2, dbias, v_rec, z_rec, a_rec = snn_models.lif_eprop(w1,wr,w2,bias,B,x_batch,y1hot_batch,cue_on,decays)
            dw1_past = 0.9*dw1_past + np.mean(dw1,0) #!!! momentum=0.9
            dw2_past = 0.9*dw2_past + np.mean(dw2,0) #!!! momentum=0.9
            dwr_past = 0.9*dwr_past + np.mean(dwr,0) #!!! momentum=0.9
            dbias_past = 0.9*dbias_past + np.mean(dbias,0) #!!! momentum=0.9 #AKSHAY
            
            w1 += dw1_past # input-->hidden update
            w2 += dw2_past # hidden-->hidden update
            wr += dwr_past # hidden-->output update
            bias += dbias_past # bias update #AKSHAY
            
            # w1 += np.mean(dw1,0) # these are for no-momentum update (slow learning)
            # w2 += np.mean(dw2,0)
            # wr += np.mean(dwr,0)
            # bias += np.mean(dbias,0)
            # np.fill_diagonal(wr,0) # no-self connectivity    

            #!!! below 5 lines are valid only for E/I network (uncomment when using random network) 
            ind_negative = wr<0
            ind = ind_negative*(~ind_fromi) # find negative & exciatory neurons
            wr[ind] = 0. # force the negative weights to 0
            ind = (~ind_negative)*ind_fromi # find positive & inhibitory neurons
            wr[ind] = 0. # force the positive weights to 0
            
            pi = np.exp(out_rec[:,cue_on,:])/np.exp(out_rec[:,cue_on,:]).sum(2).reshape(batch_size,dur_stim,1) # sfotmax /// [batch_size,dur_stim,2]
            pi_m = pi.mean(1)
            acc_batch[batch_idx] = (np.argmax(pi_m,axis=1) == y_batch[:,cue_on][:,-1]).mean() # save cc
            
            loss_batch[batch_idx] = loss.mean() # save loss
            fr_batch[batch_idx] = 1000*z_rec.mean() # save firing rate
        loss_train.append(loss_batch.mean()) # save loss 
        acc_train.append(acc_batch.mean()) # save acc
        fr_train.append(fr_batch.mean()) # save firing rate
        print('EPOCH %d TRAIN) loss: %0.4f, acc: %0.4f, fr: %0.4f Hz' %(epoch, loss_train[epoch], acc_train[epoch], fr_train[epoch]))    

        ######################### validate #########################
        x_batch,y1hot_batch,y_batch = x[-1],y1hot[-1],y[-1] # the last batch is for valid data
        loss, out_rec, dw1, dwr, dw2, dbias, v_rec, z_rec, a_rec = snn_models.lif_eprop(w1,wr,w2,bias,B,x_batch,y1hot_batch,cue_on,decays)
        
        
        pi = np.exp(out_rec[:,cue_on,:])/np.exp(out_rec[:,cue_on,:]).sum(2).reshape(batch_size,dur_stim,1) # softmax /// [batch_size,dur_stim,2]
        pi_m = pi.mean(1)
        acc_valid.append((np.argmax(pi_m,axis=1) == y_batch[:,cue_on][:,-1]).mean()) # save acc
        
        loss_valid.append(loss.mean()) # save loss
        fr_valid.append(1000*z_rec.mean()) # save firing rate
        print('EPOCH %d VALID) loss: %0.4f, acc: %0.4f, fr: %0.4f Hz' %(epoch, loss_valid[epoch], acc_valid[epoch], fr_valid[epoch]))
            
        spktr.append(z_rec[0]) # save spike train /// save one batch data only to save memory
        atr.append(a_rec[0]) # save a trace
        wrs.append(wr.copy()) # save weights
        w1s.append(w1.copy()) # save weights
        w2s.append(w2.copy()) # save weights
        biases.append(bias.copy()) # save weights
        
        ######################### save best weights #########################
        # if loss_valid[-1] == min(loss_valid): # or you can use acc criteria instead
        if acc_valid[-1] == max(acc_valid): # or you can use acc criteria instead
            w1_save,w2_save,wr_save,bias_save = w1.copy(),w2.copy(),wr.copy(),bias.copy()
            epoch_best = epoch

    # ######################### save best model ########################## never mind!!!
    # epoch_best = acc_valid.index(max(acc_valid))
    # acc_save = acc_valid[epoch_best]
    # w1_save, w2_save, wr_save, bias_save = w1s[epoch_best].copy(), w2[epoch_best].copy(), wr[epoch_best].copy(), bias[epoch_best].copy()
    print('EPOCH BEST %d VALID) loss: %0.4f, acc: %0.4f, fr: %0.4f Hz' %(epoch_best, loss_valid[epoch_best], acc_valid[epoch_best], fr_valid[epoch_best]))
    
    spktr = np.stack(spktr,0)
    atr = np.stack(atr,0)
    wrs = np.stack(wrs,0)
    N = int(n_epochs/8) # epoch interval for plotting
    
    last_acc[i] = acc_valid[-1]
    print('num_trial=', i)
# Out:
# data generated.
# (10, 256, 500, 40)
# (10, 256, 500)
# (10, 256, 500, 2)
# compile done.
# EPOCH 0 TRAIN) loss: 69
# EPOCH 18 VALID) loss: 62.1372, acc: 0.9531, fr: 7.8130 Hz
# EPOCH 19 TRAIN) loss: 62.7414, acc: 0.8086, fr: 7.9396 Hz
# EPOCH 19 VALID) loss: 61.7607, acc: 0.9844, fr: 8.1474 Hz
# EPOCH 20 TRAIN) loss: 62.1976, acc: 0.8247, fr: 8.2680 Hz
# EPOCH 20 VALID) loss: 61.2450, acc: 0.9805, fr: 8.4464 Hz
# EPOCH 21 TRAIN) loss: 62.0340, acc: 0.8294, fr: 8.5957 Hz
# EPOCH 21 VALID) loss: 60.5799, acc: 0.9727, fr: 8.7422 Hz
# EPOCH 22 TRAIN) loss: 61.6647, acc: 0.8242, fr: 8.8727 Hz
# EPOCH 22 VALID) loss: 60.6226, acc: 0.9922, fr: 9.0390 Hz
# EPOCH 23 TRAIN) loss: 61.5760, acc: 0.8155, fr: 9.1412 Hz
# EPOCH 23 VALID) loss: 59.8577, acc: 0.9648, fr: 9.3039 Hz
# EPOCH 24 TRAIN) loss: 61.3391, acc: 0.8203, fr: 9.4140 Hz
# EPOCH 24 VALID) loss: 60.3839, acc: 0.9570, fr: 9.6005 Hz
# EPOCH 25 TRAIN) loss: 61.2543, acc: 0.8299, fr: 9.7061 Hz
# EPOCH 25 VALID) loss: 60.6715, acc: 0.9453, fr: 9.9184 Hz
# EPOCH 26 TRAIN) loss: 61.3477, acc: 0.8268, fr: 9.9992 Hz
# EPOCH 26 VALID) loss: 60.6339, acc: 0.8945, fr: 10.1866 Hz
# EPOCH 27 TRAIN) loss: 61.1897, acc: 0.8229, fr: 10.3137 Hz
# EPOCH 27 VALID) loss: 60.9662, acc: 0.8750, fr: 10.5396 Hz
# EPOCH 28 TRAIN) loss: 61.4986, acc: 0.8147, fr: 10.6044 Hz
# EPOCH 28 VALID) loss: 61.7714, acc: 0.8047, fr: 10.8052 Hz
# EPOCH 29 TRAIN) loss: 61.4330, acc: 0.8108, fr: 10.9043 Hz
# EPOCH 29 VALID) loss: 61.6360, acc: 0.7891, fr: 11.1636 Hz
# EPOCH 30 TRAIN) loss: 61.2385, acc: 0.8164, fr: 11.2751 Hz
# EPOCH 30 VALID) loss: 63.1568, acc: 0.7305, fr: 11.5251 Hz
# EPOCH 31 TRAIN) loss: 60.8960, acc: 0.8472, fr: 11.6736 Hz
# EPOCH 31 VALID) loss: 62.1673, acc: 0.7852, fr: 11.9914 Hz
# EPOCH 32 TRAIN) loss: 60.7741, acc: 0.8859, fr: 12.1484 Hz
# EPOCH 32 VALID) loss: 61.0374, acc: 0.8750, fr: 12.4967 Hz
# EPOCH 33 TRAIN) loss: 60.4526, acc: 0.9349, fr: 12.6986 Hz
# EPOCH 33 VALID) loss: 60.9486, acc: 0.8945, fr: 13.0992 Hz
# EPOCH 34 TRAIN) loss: 60.4669, acc: 0.9566, fr: 13.3233 Hz
# EPOCH 34 VALID) loss: 60.7037, acc: 0.9297, fr: 13.7399 Hz
# EPOCH 35 TRAIN) loss: 60.3699, acc: 0.9579, fr: 14.0593 Hz
# EPOCH 35 VALID) loss: 60.6980, acc: 0.9297, fr: 14.4577 Hz
# EPOCH 20 VALID) loss: 64.6202, acc: 0.6562, fr: 6.8020 Hz
# EPOCH 21 TRAIN) loss: 63.7509, acc: 0.7609, fr: 6.9360 Hz
# EPOCH 21 VALID) loss: 64.6487, acc: 0.6133, fr: 6.9770 Hz
# EPOCH 22 TRAIN) loss: 63.5140, acc: 0.7431, fr: 7.1058 Hz
# EPOCH 22 VALID) loss: 64.9106, acc: 0.6016, fr: 7.1465 Hz
# EPOCH 23 TRAIN) loss: 63.8398, acc: 0.7244, fr: 7.3034 Hz
# EPOCH 23 VALID) loss: 65.5362, acc: 0.5586, fr: 7.3761 Hz
# EPOCH 24 TRAIN) loss: 63.8659, acc: 0.7127, fr: 7.5104 Hz
# EPOCH 24 VALID) loss: 65.4704, acc: 0.5664, fr: 7.5662 Hz
# EPOCH 25 TRAIN) loss: 63.8495, acc: 0.7122, fr: 7.7067 Hz
# EPOCH 25 VALID) loss: 65.2506, acc: 0.5430, fr: 7.7716 Hz
# EPOCH 26 TRAIN) loss: 63.8532, acc: 0.6970, fr: 7.8854 Hz
# EPOCH 26 VALID) loss: 66.1448, acc: 0.5000, fr: 7.9519 Hz
# EPOCH 27 TRAIN) loss: 64.2190, acc: 0.6836, fr: 8.0810 Hz
# EPOCH 27 VALID) loss: 66.5168, acc: 0.4844, fr: 8.1573 Hz
# EPOCH 28 TRAIN) loss: 64.5731, acc: 0.6740, fr: 8.2735 Hz
# EPOCH 28 VALID) loss: 66.4832, acc: 0.4844, fr: 8.3687 Hz
# EPOCH 29 TRAIN) loss: 64.8699, acc: 0.6662, fr: 8.4936 Hz
# EPOCH 29 VALID) loss: 66.9751, acc: 0.4883, fr: 8.5714 Hz
# EPOCH 30 TRAIN) loss: 65.0424, acc: 0.6476, fr: 8.7141 Hz
# EPOCH 30 VALID) loss: 66.8634, acc: 0.4883, fr: 8.7822 Hz
# EPOCH 31 TRAIN) loss: 65.4891, acc: 0.6476, fr: 8.9169 Hz
# EPOCH 31 VALID) loss: 67.0514, acc: 0.4844, fr: 9.0019 Hz
# EPOCH 32 TRAIN) loss: 65.7375, acc: 0.6489, fr: 9.1434 Hz
# EPOCH 32 VALID) loss: 65.3591, acc: 0.5273, fr: 9.1783 Hz
# EPOCH 33 TRAIN) loss: 65.7783, acc: 0.6367, fr: 9.3515 Hz
# EPOCH 33 VALID) loss: 64.4867, acc: 0.6289, fr: 9.3877 Hz
# EPOCH 34 TRAIN) loss: 65.8319, acc: 0.6111, fr: 9.5415 Hz
# EPOCH 34 VALID) loss: 62.9735, acc: 0.8242, fr: 9.5963 Hz
# EPOCH 35 TRAIN) loss: 65.4240, acc: 0.6276, fr: 9.7521 Hz
# EPOCH 35 VALID) loss: 62.8600, acc: 0.9297, fr: 9.8130 Hz
# EPOCH 36 TRAIN) loss: 64.9185, acc: 0.6554, fr: 9.9755 Hz
# EPOCH 36 VALID) loss: 62.6778, acc: 0.8867, fr: 10.0570 Hz
# EPOCH 37 TRAIN) loss: 64.4796, acc: 0.6797, fr: 10.1891 Hz
# EPOCH 24 TRAIN) loss: 66.0219, acc: 0.7513, fr: 5.1657 Hz
# EPOCH 24 VALID) loss: 65.6659, acc: 0.8164, fr: 5.2630 Hz
# EPOCH 25 TRAIN) loss: 65.9759, acc: 0.7448, fr: 5.2782 Hz
# EPOCH 25 VALID) loss: 65.9676, acc: 0.7734, fr: 5.3348 Hz
# EPOCH 26 TRAIN) loss: 66.0684, acc: 0.7309, fr: 5.3945 Hz
# EPOCH 26 VALID) loss: 65.9638, acc: 0.7812, fr: 5.4215 Hz
# EPOCH 27 TRAIN) loss: 66.0011, acc: 0.7391, fr: 5.4791 Hz
# EPOCH 27 VALID) loss: 65.8640, acc: 0.7812, fr: 5.5376 Hz
# EPOCH 28 TRAIN) loss: 65.9669, acc: 0.7405, fr: 5.5795 Hz
# EPOCH 28 VALID) loss: 65.8539, acc: 0.8281, fr: 5.6410 Hz
# EPOCH 29 TRAIN) loss: 65.8815, acc: 0.7396, fr: 5.6745 Hz
# EPOCH 29 VALID) loss: 65.5893, acc: 0.8711, fr: 5.7384 Hz
# EPOCH 30 TRAIN) loss: 65.9337, acc: 0.7348, fr: 5.7658 Hz
# EPOCH 30 VALID) loss: 65.6676, acc: 0.8750, fr: 5.8073 Hz
# EPOCH 31 TRAIN) loss: 65.8231, acc: 0.7300, fr: 5.8328 Hz
# EPOCH 31 VALID) loss: 65.5783, acc: 0.8906, fr: 5.8914 Hz
# EPOCH 32 TRAIN) loss: 65.8329, acc: 0.7253, fr: 5.9131 Hz
# EPOCH 32 VALID) loss: 65.7861, acc: 0.8789, fr: 5.9867 Hz
# EPOCH 33 TRAIN) loss: 65.8713, acc: 0.7192, fr: 5.9995 Hz
# EPOCH 33 VALID) loss: 65.5683, acc: 0.9023, fr: 6.0540 Hz
# EPOCH 34 TRAIN) loss: 65.8342, acc: 0.7174, fr: 6.0836 Hz
# EPOCH 34 VALID) loss: 65.3667, acc: 0.9141, fr: 6.1231 Hz
# EPOCH 35 TRAIN) loss: 65.7918, acc: 0.7127, fr: 6.1580 Hz
# EPOCH 35 VALID) loss: 65.5149, acc: 0.9102, fr: 6.2102 Hz
# EPOCH 36 TRAIN) loss: 65.7261, acc: 0.7101, fr: 6.2266 Hz
# EPOCH 36 VALID) loss: 65.3905, acc: 0.9023, fr: 6.2576 Hz
# EPOCH 37 TRAIN) loss: 65.7740, acc: 0.7148, fr: 6.3030 Hz
# EPOCH 37 VALID) loss: 65.4230, acc: 0.9297, fr: 6.3271 Hz
# EPOCH 38 TRAIN) loss: 65.6984, acc: 0.7036, fr: 6.3741 Hz
# EPOCH 38 VALID) loss: 65.3732, acc: 0.9414, fr: 6.4246 Hz
# EPOCH 39 TRAIN) loss: 65.6786, acc: 0.7075, fr: 6.4534 Hz
# EPOCH 39 VALID) loss: 65.1584, acc: 0.9258, fr: 6.4889 Hz
# EPOCH 40 TRAIN) loss: 65.6069, acc: 0.7105, fr: 6.5348 Hz
# EPOCH 40 VALID) loss: 65.1389, acc: 0.9258, fr: 6.5502 Hz
# EPOCH 25 VALID) loss: 64.8588, acc: 0.7383, fr: 7.4155 Hz
# EPOCH 26 TRAIN) loss: 64.0373, acc: 0.7027, fr: 7.4358 Hz
# EPOCH 26 VALID) loss: 64.2192, acc: 0.7500, fr: 7.5471 Hz
# EPOCH 27 TRAIN) loss: 63.5052, acc: 0.7192, fr: 7.5952 Hz
# EPOCH 27 VALID) loss: 63.8203, acc: 0.7344, fr: 7.6604 Hz
# EPOCH 28 TRAIN) loss: 63.2869, acc: 0.7209, fr: 7.7818 Hz
# EPOCH 28 VALID) loss: 63.4325, acc: 0.7695, fr: 7.9141 Hz
# EPOCH 29 TRAIN) loss: 62.9923, acc: 0.7214, fr: 8.0257 Hz
# EPOCH 29 VALID) loss: 62.8471, acc: 0.8086, fr: 8.1748 Hz
# EPOCH 30 TRAIN) loss: 62.7107, acc: 0.7270, fr: 8.3336 Hz
# EPOCH 30 VALID) loss: 62.2569, acc: 0.8008, fr: 8.4909 Hz
# EPOCH 31 TRAIN) loss: 62.3784, acc: 0.7335, fr: 8.6344 Hz
# EPOCH 31 VALID) loss: 61.9014, acc: 0.8516, fr: 8.8211 Hz
# EPOCH 32 TRAIN) loss: 62.1147, acc: 0.7378, fr: 8.9509 Hz
# EPOCH 32 VALID) loss: 61.9512, acc: 0.8633, fr: 9.1231 Hz
# EPOCH 33 TRAIN) loss: 62.0145, acc: 0.7435, fr: 9.2627 Hz
# EPOCH 33 VALID) loss: 61.2116, acc: 0.8945, fr: 9.4125 Hz
# EPOCH 34 TRAIN) loss: 62.0152, acc: 0.7500, fr: 9.5939 Hz
# EPOCH 34 VALID) loss: 60.5723, acc: 0.9688, fr: 9.7719 Hz
# EPOCH 35 TRAIN) loss: 61.8709, acc: 0.7669, fr: 9.9195 Hz
# EPOCH 35 VALID) loss: 60.4636, acc: 0.9883, fr: 10.0773 Hz
# EPOCH 36 TRAIN) loss: 61.6397, acc: 0.7734, fr: 10.2304 Hz
# EPOCH 36 VALID) loss: 60.6682, acc: 0.9883, fr: 10.3657 Hz
# EPOCH 37 TRAIN) loss: 61.6446, acc: 0.7739, fr: 10.5487 Hz
# EPOCH 37 VALID) loss: 59.8004, acc: 0.9688, fr: 10.7058 Hz
# EPOCH 38 TRAIN) loss: 61.4886, acc: 0.7804, fr: 10.8984 Hz
# EPOCH 38 VALID) loss: 59.7127, acc: 0.9453, fr: 11.0714 Hz
# EPOCH 39 TRAIN) loss: 61.3471, acc: 0.7886, fr: 11.2600 Hz
# EPOCH 39 VALID) loss: 60.4893, acc: 0.9023, fr: 11.4597 Hz
# EPOCH 40 TRAIN) loss: 60.8590, acc: 0.8212, fr: 11.6535 Hz
# EPOCH 40 VALID) loss: 60.0542, acc: 0.8672, fr: 11.9041 Hz
# EPOCH 41 TRAIN) loss: 60.5311, acc: 0.8598, fr: 12.1025 Hz
# EPOCH 41 VALID) loss: 59.9841, acc: 0.9102, fr: 12.3376 Hz
# EPOCH 42 TRAIN) loss: 60.3550, acc: 0.9102, fr: 12.5741 Hz
# EPOCH 42 VALID) loss: 59.9026, acc: 0.9258, fr: 12.8410 Hz
# EPOCH 43 TRAIN) loss: 60.0679, acc: 0.9249, fr: 13.0580 Hz
# EPOCH 43 VALID) loss: 59.7063, acc: 0.9648, fr: 13.3128 Hz
# EPOCH 44 TRAIN) loss: 60.3693, acc: 0.9306, fr: 13.5808 Hz
# EPOCH 44 VALID) loss: 60.1687, acc: 0.9492, fr: 13.8828 Hz
# EPOCH 45 TRAIN) loss: 60.5236, acc: 0.9384, fr: 14.0406 Hz
# EPOCH 45 VALID) loss: 61.3797, acc: 0.9336, fr: 14.3285 Hz
# EPOCH 46 TRAIN) loss: 61.0816, acc: 0.9401, fr: 14.5655 Hz
# EPOCH 46 VALID) loss: 61.1481, acc: 0.9609, fr: 14.8760 Hz
# EPOCH 47 TRAIN) loss: 61.4618, acc: 0.9418, fr: 15.1139 Hz
# EPOCH 47 VALID) loss: 61.6414, acc: 0.9609, fr: 15.4782 Hz
# EPOCH 48 TRAIN) loss: 62.2380, acc: 0.9384, fr: 15.7262 Hz
# EPOCH 48 VALID) loss: 62.1931, acc: 0.9570, fr: 16.1769 Hz
# EPOCH 49 TRAIN) loss: 62.6423, acc: 0.9418, fr: 16.4570 Hz
# EPOCH 49 VALID) loss: 62.5767, acc: 0.9492, fr: 16.7940 Hz
# num_trial= 4
# data generated.
# (10, 256, 500, 40)
# (10, 256, 500)
# (10, 256, 500, 2)
# compile done.
# EPOCH 0 TRAIN) loss: 69.4256, acc: 0.5143, fr: 0.3846 Hz
# EPOCH 0 VALID) loss: 70.1566, acc: 0.4531, fr: 0.3976 Hz
# EPOCH 1 TRAIN) loss: 69.6974, acc: 0.4926, fr: 0.4225 Hz
# EPOCH 1 VALID) loss: 70.4710, acc: 0.4531, fr: 0.4660 Hz
# EPOCH 2 TRAIN) loss: 69.8808, acc: 0.4944, fr: 0.5215 Hz
# EPOCH 2 VALID) loss: 70.3066, acc: 0.4531, fr: 0.5877 Hz
# EPOCH 3 TRAIN) loss: 69.9156, acc: 0.4935, fr: 0.6570 Hz
# EPOCH 3 VALID) loss: 70.0713, acc: 0.4531, fr: 0.7293 Hz
# EPOCH 4 TRAIN) loss: 69.8509, acc: 0.4944, fr: 0.8246 Hz
# EPOCH 4 VALID) loss: 69.8801, acc: 0.4531, fr: 0.9253 Hz
# EPOCH 5 TRAIN) loss: 69.7381, acc: 0.4970, fr: 1.0608 Hz
# EPOCH 5 VALID) loss: 69.7668, acc: 0.4531, fr: 1.2114 Hz
# EPOCH 6 TRAIN) loss: 69.6556, acc: 0.4961, fr: 1.3725 Hz
# EPOCH 6 VALID) loss: 69.7106, acc: 0.4531, fr: 1.5199 Hz
# EPOCH 7 TRAIN) loss: 69.5639, acc: 0.5004, fr: 1.6774 Hz
# EPOCH 7 VALID) loss: 69.6249, acc: 0.4531, fr: 1.8255 Hz
# EPOCH 8 TRAIN) loss: 69.3762, acc: 0.5122, fr: 2.0070 Hz
# EPOCH 8 VALID) loss: 69.4270, acc: 0.4570, fr: 2.2045 Hz
# EPOCH 9 TRAIN) loss: 69.0043, acc: 0.5378, fr: 2.3578 Hz
# EPOCH 9 VALID) loss: 68.9238, acc: 0.4531, fr: 2.5890 Hz
# EPOCH 10 TRAIN) loss: 68.4384, acc: 0.5677, fr: 2.7634 Hz
# EPOCH 10 VALID) loss: 68.3068, acc: 0.4688, fr: 3.0196 Hz
# EPOCH 11 TRAIN) loss: 67.7119, acc: 0.5959, fr: 3.1940 Hz
# EPOCH 11 VALID) loss: 67.2168, acc: 0.6484, fr: 3.4959 Hz
# EPOCH 12 TRAIN) loss: 66.7781, acc: 0.6593, fr: 3.7386 Hz
# EPOCH 12 VALID) loss: 66.3622, acc: 0.7539, fr: 4.1303 Hz
# EPOCH 13 TRAIN) loss: 65.8700, acc: 0.7326, fr: 4.3956 Hz
# EPOCH 13 VALID) loss: 65.5091, acc: 0.8320, fr: 4.7460 Hz
# EPOCH 14 TRAIN) loss: 65.2451, acc: 0.7821, fr: 4.9401 Hz
# EPOCH 14 VALID) loss: 65.0521, acc: 0.8398, fr: 5.2421 Hz
# EPOCH 15 TRAIN) loss: 64.5514, acc: 0.8173, fr: 5.4645 Hz
# EPOCH 15 VALID) loss: 64.5102, acc: 0.8711, fr: 5.8032 Hz
# EPOCH 16 TRAIN) loss: 64.4974, acc: 0.8403, fr: 5.9175 Hz
# EPOCH 16 VALID) loss: 63.9553, acc: 0.9023, fr: 6.1941 Hz
# EPOCH 17 TRAIN) loss: 64.7454, acc: 0.8429, fr: 6.2730 Hz
# EPOCH 17 VALID) loss: 64.3645, acc: 0.8750, fr: 6.5269 Hz
# EPOCH 18 TRAIN) loss: 64.4971, acc: 0.8303, fr: 6.6311 Hz
# EPOCH 18 VALID) loss: 64.1614, acc: 0.8125, fr: 6.8955 Hz
# EPOCH 19 TRAIN) loss: 64.2960, acc: 0.7873, fr: 6.9892 Hz
# EPOCH 19 VALID) loss: 64.2292, acc: 0.7852, fr: 7.2354 Hz
# EPOCH 20 TRAIN) loss: 64.2557, acc: 0.7626, fr: 7.2434 Hz
# EPOCH 20 VALID) loss: 64.1735, acc: 0.7539, fr: 7.4180 Hz
# EPOCH 21 TRAIN) loss: 64.2112, acc: 0.7448, fr: 7.4429 Hz
# EPOCH 21 VALID) loss: 64.7937, acc: 0.7109, fr: 7.6523 Hz
# EPOCH 22 TRAIN) loss: 64.2738, acc: 0.7218, fr: 7.6733 Hz
# EPOCH 22 VALID) loss: 65.0564, acc: 0.7031, fr: 7.8783 Hz
# EPOCH 23 TRAIN) loss: 64.1147, acc: 0.7179, fr: 7.8916 Hz
# EPOCH 23 VALID) loss: 65.0587, acc: 0.6836, fr: 8.1220 Hz
# EPOCH 24 TRAIN) loss: 64.2360, acc: 0.7062, fr: 8.0928 Hz
# EPOCH 24 VALID) loss: 65.1566, acc: 0.6836, fr: 8.2628 Hz
# EPOCH 25 TRAIN) loss: 64.0591, acc: 0.6962, fr: 8.2641 Hz
# EPOCH 25 VALID) loss: 64.5095, acc: 0.6953, fr: 8.5096 Hz
# EPOCH 26 TRAIN) loss: 63.6193, acc: 0.7122, fr: 8.4518 Hz
# EPOCH 26 VALID) loss: 64.4955, acc: 0.6992, fr: 8.6629 Hz
# EPOCH 27 TRAIN) loss: 63.2567, acc: 0.7253, fr: 8.6105 Hz
# EPOCH 27 VALID) loss: 64.4759, acc: 0.7109, fr: 8.7808 Hz
# EPOCH 28 TRAIN) loss: 63.0181, acc: 0.7370, fr: 8.7843 Hz
# EPOCH 28 VALID) loss: 64.3914, acc: 0.7305, fr: 9.0147 Hz
# EPOCH 29 TRAIN) loss: 62.7189, acc: 0.7461, fr: 9.0401 Hz
# EPOCH 29 VALID) loss: 63.6541, acc: 0.7344, fr: 9.2830 Hz
# EPOCH 30 TRAIN) loss: 62.8226, acc: 0.7539, fr: 9.3924 Hz
# EPOCH 30 VALID) loss: 63.5399, acc: 0.7383, fr: 9.6491 Hz
# EPOCH 31 TRAIN) loss: 62.4975, acc: 0.7613, fr: 9.7553 Hz
# EPOCH 31 VALID) loss: 62.8891, acc: 0.7734, fr: 10.0316 Hz
# EPOCH 32 TRAIN) loss: 62.0999, acc: 0.7687, fr: 10.1311 Hz
# EPOCH 32 VALID) loss: 62.0511, acc: 0.8242, fr: 10.3672 Hz
# EPOCH 33 TRAIN) loss: 61.8633, acc: 0.7878, fr: 10.5094 Hz
# EPOCH 33 VALID) loss: 61.1432, acc: 0.8750, fr: 10.7789 Hz
# EPOCH 34 TRAIN) loss: 61.5300, acc: 0.8090, fr: 10.8740 Hz
# EPOCH 34 VALID) loss: 60.1369, acc: 0.9414, fr: 11.1366 Hz
# EPOCH 35 TRAIN) loss: 60.9725, acc: 0.8485, fr: 11.2540 Hz
# EPOCH 35 VALID) loss: 59.6709, acc: 0.9414, fr: 11.5064 Hz
# EPOCH 36 TRAIN) loss: 60.9138, acc: 0.8737, fr: 11.6229 Hz
# EPOCH 36 VALID) loss: 60.1628, acc: 0.9609, fr: 11.8920 Hz
# EPOCH 37 TRAIN) loss: 60.9737, acc: 0.9032, fr: 12.0159 Hz
# EPOCH 37 VALID) loss: 60.6319, acc: 0.9766, fr: 12.2653 Hz
# EPOCH 38 TRAIN) loss: 60.9292, acc: 0.9141, fr: 12.4539 Hz
# EPOCH 38 VALID) loss: 60.5699, acc: 0.9766, fr: 12.7026 Hz
# EPOCH 39 TRAIN) loss: 60.8524, acc: 0.9141, fr: 12.9034 Hz
# EPOCH 39 VALID) loss: 60.7125, acc: 0.9648, fr: 13.1605 Hz
# EPOCH 40 TRAIN) loss: 60.8862, acc: 0.9240, fr: 13.3978 Hz
# EPOCH 40 VALID) loss: 60.1882, acc: 0.9570, fr: 13.6155 Hz
# EPOCH 41 TRAIN) loss: 60.9465, acc: 0.9327, fr: 13.8557 Hz
# EPOCH 41 VALID) loss: 60.1675, acc: 0.9688, fr: 14.1476 Hz
# EPOCH 42 TRAIN) loss: 61.3110, acc: 0.9288, fr: 14.3352 Hz
# EPOCH 42 VALID) loss: 60.8473, acc: 0.9570, fr: 14.5779 Hz
# EPOCH 43 TRAIN) loss: 61.5079, acc: 0.9223, fr: 14.7532 Hz
# EPOCH 43 VALID) loss: 60.9563, acc: 0.9648, fr: 15.0460 Hz
# EPOCH 44 TRAIN) loss: 61.4212, acc: 0.9336, fr: 15.2380 Hz
# EPOCH 29 TRAIN) loss: 65.7231, acc: 0.6966, fr: 9.4155 Hz
# EPOCH 29 VALID) loss: 65.2575, acc: 0.8945, fr: 9.4930 Hz
# EPOCH 30 TRAIN) loss: 65.5731, acc: 0.7023, fr: 9.5618 Hz
# EPOCH 30 VALID) loss: 65.1228, acc: 0.8867, fr: 9.6437 Hz
# EPOCH 31 TRAIN) loss: 65.4266, acc: 0.7153, fr: 9.6911 Hz
# EPOCH 31 VALID) loss: 65.0208, acc: 0.8984, fr: 9.7674 Hz
# EPOCH 32 TRAIN) loss: 65.3582, acc: 0.7192, fr: 9.8222 Hz
# EPOCH 32 VALID) loss: 65.0447, acc: 0.8398, fr: 9.8836 Hz
# EPOCH 33 TRAIN) loss: 65.2662, acc: 0.7279, fr: 9.9503 Hz
# EPOCH 33 VALID) loss: 64.8205, acc: 0.8477, fr: 10.0392 Hz
# EPOCH 34 TRAIN) loss: 65.2083, acc: 0.7313, fr: 10.0700 Hz
# EPOCH 34 VALID) loss: 64.8907, acc: 0.8125, fr: 10.1712 Hz
# EPOCH 35 TRAIN) loss: 65.1050, acc: 0.7461, fr: 10.1848 Hz
# EPOCH 35 VALID) loss: 64.8526, acc: 0.8242, fr: 10.2039 Hz
# EPOCH 36 TRAIN) loss: 65.0578, acc: 0.7543, fr: 10.2801 Hz
# EPOCH 36 VALID) loss: 64.9495, acc: 0.7852, fr: 10.3115 Hz
# EPOCH 37 TRAIN) loss: 64.9818, acc: 0.7548, fr: 10.3728 Hz
# EPOCH 37 VALID) loss: 64.8054, acc: 0.7969, fr: 10.4190 Hz
# EPOCH 38 TRAIN) loss: 64.8736, acc: 0.7700, fr: 10.4605 Hz
# EPOCH 38 VALID) loss: 64.9697, acc: 0.7812, fr: 10.5512 Hz
# EPOCH 39 TRAIN) loss: 64.8175, acc: 0.7695, fr: 10.5659 Hz
# EPOCH 39 VALID) loss: 64.7388, acc: 0.7773, fr: 10.6459 Hz
# EPOCH 40 TRAIN) loss: 64.7023, acc: 0.7817, fr: 10.6559 Hz
# EPOCH 40 VALID) loss: 64.8838, acc: 0.7617, fr: 10.7068 Hz
# EPOCH 41 TRAIN) loss: 64.6712, acc: 0.7882, fr: 10.7541 Hz
# EPOCH 41 VALID) loss: 64.7369, acc: 0.7617, fr: 10.8350 Hz
# EPOCH 42 TRAIN) loss: 64.5333, acc: 0.8025, fr: 10.8445 Hz
# EPOCH 42 VALID) loss: 64.8559, acc: 0.7812, fr: 10.9222 Hz
# EPOCH 43 TRAIN) loss: 64.4343, acc: 0.7990, fr: 10.9385 Hz
# EPOCH 43 VALID) loss: 64.9347, acc: 0.7656, fr: 11.0723 Hz
# EPOCH 44 TRAIN) loss: 64.4146, acc: 0.8056, fr: 11.0578 Hz
# EPOCH 44 VALID) loss: 64.8798, acc: 0.7500, fr: 11.1426 Hz
# EPOCH 45 TRAIN) loss: 64.3829, acc: 0.8086, fr: 11.1673 Hz
# EPOCH 45 VALID) loss: 64.8247, acc: 0.7734, fr: 11.2239 Hz
# EPOCH 48 TRAIN) loss: 62.4347, acc: 0.9115, fr: 12.0462 Hz
# EPOCH 48 VALID) loss: 61.4761, acc: 0.9297, fr: 12.1809 Hz
# EPOCH 49 TRAIN) loss: 62.4453, acc: 0.9058, fr: 12.2059 Hz
# EPOCH 49 VALID) loss: 61.6888, acc: 0.9375, fr: 12.3809 Hz
# num_trial= 7
# data generated.
# (10, 256, 500, 40)
# (10, 256, 500)
# (10, 256, 500, 2)
# compile done.
# EPOCH 0 TRAIN) loss: 69.6189, acc: 0.5017, fr: 0.5238 Hz
# EPOCH 0 VALID) loss: 69.9688, acc: 0.4922, fr: 0.5458 Hz
# EPOCH 1 TRAIN) loss: 70.2423, acc: 0.4970, fr: 0.5873 Hz
# EPOCH 1 VALID) loss: 70.2951, acc: 0.4922, fr: 0.6492 Hz
# EPOCH 2 TRAIN) loss: 70.6822, acc: 0.4952, fr: 0.7371 Hz
# EPOCH 2 VALID) loss: 70.0541, acc: 0.4922, fr: 0.8664 Hz
# EPOCH 3 TRAIN) loss: 70.7497, acc: 0.4891, fr: 0.9979 Hz
# EPOCH 3 VALID) loss: 69.7331, acc: 0.4922, fr: 1.1681 Hz
# EPOCH 4 TRAIN) loss: 70.4848, acc: 0.4891, fr: 1.3544 Hz
# EPOCH 4 VALID) loss: 69.2645, acc: 0.4922, fr: 1.6161 Hz
# EPOCH 5 TRAIN) loss: 69.8262, acc: 0.5065, fr: 1.8478 Hz
# EPOCH 5 VALID) loss: 68.5943, acc: 0.4922, fr: 2.2110 Hz
# EPOCH 6 TRAIN) loss: 69.3160, acc: 0.5386, fr: 2.5217 Hz
# EPOCH 6 VALID) loss: 68.5056, acc: 0.4961, fr: 2.9183 Hz
# EPOCH 7 TRAIN) loss: 69.0722, acc: 0.5569, fr: 3.1606 Hz
# EPOCH 7 VALID) loss: 68.2289, acc: 0.4922, fr: 3.4755 Hz
# EPOCH 8 TRAIN) loss: 68.7600, acc: 0.5864, fr: 3.7010 Hz
# EPOCH 8 VALID) loss: 68.4721, acc: 0.4922, fr: 4.0255 Hz
# EPOCH 9 TRAIN) loss: 68.7803, acc: 0.5768, fr: 4.2551 Hz
# EPOCH 9 VALID) loss: 68.6674, acc: 0.4922, fr: 4.5303 Hz
# EPOCH 10 TRAIN) loss: 68.8651, acc: 0.5664, fr: 4.6836 Hz
# EPOCH 10 VALID) loss: 68.9075, acc: 0.4922, fr: 4.9028 Hz
# EPOCH 11 TRAIN) loss: 68.8100, acc: 0.5460, fr: 5.0141 Hz
# EPOCH 11 VALID) loss: 69.1691, acc: 0.4922, fr: 5.2014 Hz
# EPOCH 12 TRAIN) loss: 68.7504, acc: 0.5434, fr: 5.2686 Hz
# EPOCH 12 VALID) loss: 69.4289, acc: 0.4922, fr: 5.3873 Hz
# EPOCH 13 TRAIN) loss: 68.6231, acc: 0.5486, fr: 5.4233 Hz
# EPOCH 13 VALID) loss: 69.9924, acc: 0.4922, fr: 5.4513 Hz
# EPOCH 14 TRAIN) loss: 68.6037, acc: 0.5577, fr: 5.5288 Hz
# EPOCH 14 VALID) loss: 70.1164, acc: 0.4922, fr: 5.5864 Hz
# EPOCH 15 TRAIN) loss: 68.5052, acc: 0.5729, fr: 5.6015 Hz
# EPOCH 15 VALID) loss: 70.2132, acc: 0.4922, fr: 5.5806 Hz
# EPOCH 16 TRAIN) loss: 68.5352, acc: 0.5781, fr: 5.6463 Hz
# EPOCH 16 VALID) loss: 70.4798, acc: 0.4922, fr: 5.6588 Hz
# EPOCH 17 TRAIN) loss: 68.4081, acc: 0.5846, fr: 5.6821 Hz
# EPOCH 17 VALID) loss: 70.3681, acc: 0.4922, fr: 5.6845 Hz
# EPOCH 18 TRAIN) loss: 68.2437, acc: 0.5959, fr: 5.7693 Hz
# EPOCH 18 VALID) loss: 70.3426, acc: 0.4922, fr: 5.8238 Hz
# EPOCH 19 TRAIN) loss: 68.2533, acc: 0.5898, fr: 5.8860 Hz
# EPOCH 19 VALID) loss: 70.5194, acc: 0.4922, fr: 5.9516 Hz
# EPOCH 20 TRAIN) loss: 68.1137, acc: 0.5955, fr: 6.0563 Hz
# EPOCH 20 VALID) loss: 70.0313, acc: 0.4922, fr: 6.1213 Hz
# EPOCH 21 TRAIN) loss: 67.7279, acc: 0.5959, fr: 6.2366 Hz
# EPOCH 21 VALID) loss: 69.9090, acc: 0.4922, fr: 6.2882 Hz
# EPOCH 22 TRAIN) loss: 67.5229, acc: 0.5972, fr: 6.4054 Hz
# EPOCH 22 VALID) loss: 70.1590, acc: 0.4922, fr: 6.4946 Hz
# EPOCH 23 TRAIN) loss: 67.2267, acc: 0.5924, fr: 6.6116 Hz
# EPOCH 23 VALID) loss: 69.4409, acc: 0.4922, fr: 6.7009 Hz
# EPOCH 24 TRAIN) loss: 66.8776, acc: 0.5955, fr: 6.8334 Hz
# EPOCH 24 VALID) loss: 68.5216, acc: 0.5000, fr: 6.9168 Hz
# EPOCH 25 TRAIN) loss: 66.6189, acc: 0.5985, fr: 7.1071 Hz
# EPOCH 25 VALID) loss: 68.2956, acc: 0.5000, fr: 7.1993 Hz
# EPOCH 26 TRAIN) loss: 66.1538, acc: 0.6155, fr: 7.3656 Hz
# EPOCH 26 VALID) loss: 67.9066, acc: 0.5156, fr: 7.4953 Hz
# EPOCH 27 TRAIN) loss: 65.8942, acc: 0.6402, fr: 7.6436 Hz
# EPOCH 27 VALID) loss: 66.8446, acc: 0.5781, fr: 7.7450 Hz
# EPOCH 28 TRAIN) loss: 65.5161, acc: 0.6515, fr: 7.9248 Hz
# EPOCH 28 VALID) loss: 65.2897, acc: 0.6680, fr: 8.0404 Hz
# EPOCH 29 TRAIN) loss: 65.0511, acc: 0.6671, fr: 8.2215 Hz
# EPOCH 29 VALID) loss: 64.5274, acc: 0.8281, fr: 8.3778 Hz
# EPOCH 30 TRAIN) loss: 64.6237, acc: 0.6970, fr: 8.5476 Hz
# EPOCH 30 VALID) loss: 64.2173, acc: 0.9219, fr: 8.6551 Hz
# EPOCH 31 TRAIN) loss: 64.1073, acc: 0.7465, fr: 8.8699 Hz
# EPOCH 31 VALID) loss: 63.9193, acc: 0.9023, fr: 9.0320 Hz
# EPOCH 32 TRAIN) loss: 63.7072, acc: 0.7930, fr: 9.2157 Hz
# EPOCH 17 TRAIN) loss: 63.2338, acc: 0.9136, fr: 5.2486 Hz
# EPOCH 17 VALID) loss: 63.1115, acc: 0.9766, fr: 5.3167 Hz
# EPOCH 18 TRAIN) loss: 63.0742, acc: 0.9145, fr: 5.4460 Hz
# EPOCH 18 VALID) loss: 62.5536, acc: 0.9766, fr: 5.4964 Hz
# EPOCH 19 TRAIN) loss: 62.8123, acc: 0.9167, fr: 5.6278 Hz
# EPOCH 19 VALID) loss: 62.2837, acc: 0.9727, fr: 5.7099 Hz
# EPOCH 20 TRAIN) loss: 62.6430, acc: 0.9119, fr: 5.8280 Hz
# EPOCH 20 VALID) loss: 62.3938, acc: 0.9688, fr: 5.9237 Hz
# EPOCH 21 TRAIN) loss: 62.6143, acc: 0.9032, fr: 6.0228 Hz
# EPOCH 21 VALID) loss: 62.0823, acc: 0.9688, fr: 6.0953 Hz
# EPOCH 22 TRAIN) loss: 62.4511, acc: 0.9019, fr: 6.2217 Hz
# EPOCH 22 VALID) loss: 62.4457, acc: 0.9492, fr: 6.2462 Hz
# EPOCH 23 TRAIN) loss: 62.2726, acc: 0.8967, fr: 6.4566 Hz
# EPOCH 23 VALID) loss: 62.1785, acc: 0.9609, fr: 6.5804 Hz
# EPOCH 24 TRAIN) loss: 62.3413, acc: 0.9010, fr: 6.6782 Hz
# EPOCH 24 VALID) loss: 61.7864, acc: 0.9531, fr: 6.8035 Hz
# EPOCH 25 TRAIN) loss: 62.4108, acc: 0.9015, fr: 6.9355 Hz
# EPOCH 25 VALID) loss: 62.4707, acc: 0.9336, fr: 7.0129 Hz
# EPOCH 26 TRAIN) loss: 62.2453, acc: 0.8989, fr: 7.1904 Hz
# EPOCH 26 VALID) loss: 62.1046, acc: 0.9609, fr: 7.2897 Hz
# EPOCH 27 TRAIN) loss: 62.4996, acc: 0.8937, fr: 7.4378 Hz
# EPOCH 27 VALID) loss: 61.6140, acc: 0.9648, fr: 7.5484 Hz
# EPOCH 28 TRAIN) loss: 62.6792, acc: 0.8885, fr: 7.7062 Hz
# EPOCH 28 VALID) loss: 61.5504, acc: 0.9531, fr: 7.8194 Hz
# EPOCH 29 TRAIN) loss: 62.5730, acc: 0.8859, fr: 7.9921 Hz
# EPOCH 29 VALID) loss: 61.9704, acc: 0.9258, fr: 8.0841 Hz
# EPOCH 30 TRAIN) loss: 62.7828, acc: 0.8728, fr: 8.2911 Hz
# EPOCH 30 VALID) loss: 61.8006, acc: 0.9727, fr: 8.4291 Hz
# EPOCH 31 TRAIN) loss: 62.8261, acc: 0.8650, fr: 8.6054 Hz
# EPOCH 31 VALID) loss: 62.2803, acc: 0.9609, fr: 8.7401 Hz
# EPOCH 32 TRAIN) loss: 63.0975, acc: 0.8568, fr: 8.9446 Hz
# EPOCH 32 VALID) loss: 62.2388, acc: 0.9336, fr: 9.1753 Hz
# EPOCH 33 TRAIN) loss: 63.1652, acc: 0.8555, fr: 9.3766 Hz
# EPOCH 33 VALID) loss: 62.3150, acc: 0.9141, fr: 9.5824 Hz
# EPOCH 34 TRAIN) loss: 63.1720, acc: 0.8498, fr: 9.7804 Hz
# EPOCH 34 VALID) loss: 62.0742, acc: 0.8945, fr: 9.9836 Hz
# EPOCH 35 TRAIN) loss: 63.4167, acc: 0.8477, fr: 10.2423 Hz
# EPOCH 35 VALID) loss: 63.0321, acc: 0.8281, fr: 10.4785 Hz
# EPOCH 36 TRAIN) loss: 63.4802, acc: 0.8641, fr: 10.7672 Hz
# EPOCH 36 VALID) loss: 63.1620, acc: 0.8320, fr: 11.0539 Hz
# EPOCH 37 TRAIN) loss: 63.7147, acc: 0.8672, fr: 11.3741 Hz
# EPOCH 37 VALID) loss: 62.9250, acc: 0.8555, fr: 11.6573 Hz
# EPOCH 38 TRAIN) loss: 64.0877, acc: 0.8728, fr: 12.0773 Hz
# EPOCH 38 VALID) loss: 63.4127, acc: 0.8750, fr: 12.4481 Hz
# EPOCH 39 TRAIN) loss: 64.2755, acc: 0.8872, fr: 12.9136 Hz
# EPOCH 39 VALID) loss: 64.3213, acc: 0.8789, fr: 13.3891 Hz
# EPOCH 40 TRAIN) loss: 64.7729, acc: 0.8576, fr: 13.8665 Hz
# EPOCH 40 VALID) loss: 64.4137, acc: 0.8828, fr: 14.4511 Hz
# EPOCH 41 TRAIN) loss: 65.1447, acc: 0.8537, fr: 14.8971 Hz
# EPOCH 41 VALID) loss: 65.1029, acc: 0.8477, fr: 15.3677 Hz
# EPOCH 42 TRAIN) loss: 65.5217, acc: 0.8459, fr: 15.9231 Hz
# EPOCH 42 VALID) loss: 65.1837, acc: 0.8828, fr: 16.4504 Hz
# EPOCH 43 TRAIN) loss: 65.8558, acc: 0.8286, fr: 16.9404 Hz
# EPOCH 43 VALID) loss: 65.8822, acc: 0.9062, fr: 17.3977 Hz
# EPOCH 44 TRAIN) loss: 66.1306, acc: 0.8021, fr: 17.9522 Hz
# EPOCH 44 VALID) loss: 65.8458, acc: 0.8789, fr: 18.4041 Hz
# EPOCH 45 TRAIN) loss: 66.4468, acc: 0.7747, fr: 19.0229 Hz
# EPOCH 45 VALID) loss: 65.6927, acc: 0.8594, fr: 19.4923 Hz
# EPOCH 46 TRAIN) loss: 66.6794, acc: 0.7622, fr: 20.0487 Hz
# EPOCH 46 VALID) loss: 66.3054, acc: 0.8945, fr: 20.4570 Hz
# EPOCH 47 TRAIN) loss: 67.3822, acc: 0.7075, fr: 20.9226 Hz
# EPOCH 47 VALID) loss: 67.0024, acc: 0.8867, fr: 21.2813 Hz
# EPOCH 48 TRAIN) loss: 68.0919, acc: 0.6554, fr: 21.6992 Hz
# EPOCH 48 VALID) loss: 66.9473, acc: 0.8438, fr: 21.9573 Hz
# EPOCH 49 TRAIN) loss: 68.6287, acc: 0.6081, fr: 22.3540 Hz
# EPOCH 49 VALID) loss: 67.1017, acc: 0.8203, fr: 22.5336 Hz
# num_trial= 9

# %%
last_acc
# Out:
# array([0.51953125, 0.79296875, 0.875     , 0.890625  , 0.94921875,
#        0.9453125 , 0.76953125, 0.9375    , 0.79296875, 0.8203125 ])

# %%
np.mean(last_acc)
# Out:
# 0.829296875
