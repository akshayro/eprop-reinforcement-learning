# %%
import numpy as np
import matplotlib.pyplot as plt
import spikes4 as spk4
import snn_models

import scipy.io as sio #allows for importing of .mat files 
from elephant.spike_train_generation import homogeneous_poisson_process
from quantities import Hz, s, ms

# %% [markdown]
# # Parameters

# %%
#%% parameters
time_step = 1 # 1ms time resolution

lr = 0.002 # learning rate 0.005
thr = 0.6 # v threshold
tau_out = 3 # output decay time constant /// unit: ms
kappa = np.exp(-time_step/tau_out) # output decay
tau_mem = 20 # v decay time constant /// unit: ms
alpha = np.exp(-time_step/tau_mem) # v decay
beta = 0.2 # adaptation increment 
tau_a = 200 # adaptation decay time constant /// unit: ms
rho = np.exp(-time_step/(tau_a+1e-12)) # adaptation decay
t_ref = 2 # refractory period /// unit: ms

decays = np.array([lr, thr, alpha, beta, kappa, rho, t_ref]) # save as a vector

# %% [markdown]
# #  Neural data input preparation

# %%
nb_inputs, nb_hidden, nb_outputs  = 27, 100, 5 # number of neurons

rootDir = ''
fn = 'ecogclassifydata.mat'

# conv_size = 3 # size of time history

# load the mat file
mat = sio.loadmat(rootDir+fn)
x = mat['powervals']
y = mat['group']

# Normalize 0-1
x_norm = (x - np.min(x)) / (np.max(x) - np.min(x))


# Generate spike train
# I used the method described in https://praneethnamburi.com/2015/02/05/simulating-neural-spike-trains/
# Much more simple
import random
T = 0.1  # total time in sec
dt = 0.001  # time interval in sec
bins = int(T / dt)  
x_spikes = np.zeros((1, x_norm.shape[0],bins,x_norm.shape[1]))
random.seed(9)
for ss in range(0,x_norm.shape[0]):
    for nn in range(0,x_norm.shape[1]):
        xt = x_norm[ss,nn]
        fr = xt * 100  # firing rate in Hz (range 0-100)
        for bb in range(bins):
            p = random.random()
            if p < fr * dt:
                x_spikes[0,ss,bb,nn] = 1 # spike

y_in = np.zeros((1,y.shape[0],bins,1))
y1hot = np.zeros((1,y.shape[0],bins,5))
for ss in range(y.shape[0]):
    y_in[0,ss,:,0] = y[ss]
    y1hot[0,ss,:,y[ss]-1] = 1

print(x_spikes.shape)
print(y_in.shape)

# Larger value of x corresponds to more spikes = good
print(x_norm[0,0])
print(np.sum(x_spikes[0,0,:,0]))
print(x_norm[15,5])
print(np.sum(x_spikes[0,15,:,5]))
cue_on = np.zeros((100),dtype=bool)

# Not sure how to set the learning cue
dur_stim = 1
cue_on[(100-dur_stim):] = 1

x = x_spikes
y = y_in
# Out:
# (1, 39, 100, 27)
# (1, 39, 100, 1)
# 0.3037128335044352
# 5.0
# 0.7995052914718683
# 10.0

# %% [markdown]
# # Initialize weights

# %%
#%% initialize weight
weight_scale = 10*(1.0-alpha) #!!!
w1 = np.random.normal(size=(nb_inputs,nb_hidden), loc=0.0, scale=weight_scale/np.sqrt(nb_inputs)) # input-->hidden
w2 = np.random.normal(size=(nb_hidden,nb_outputs), loc=0.0, scale=weight_scale/np.sqrt(nb_hidden)) # hidden-->hidden
#bias = np.random.normal(size=(nb_outputs), loc=0.0, scale=weight_scale/np.sqrt(nb_outputs)) # output bias
bias = np.zeros(nb_outputs) # output bias
B = np.random.normal(size=(nb_outputs,nb_hidden), loc=0.0, scale=weight_scale/np.sqrt(nb_outputs)) #!!! random e-prop

# %%
#%% recurrent weights (choose only one)
############### (1) random network ###############
# wr = np.random.normal(size=(nb_hidden,nb_hidden), loc=0.0, scale=weight_scale/np.sqrt(nb_hidden)) # hidden-->output
# np.fill_diagonal(wr,0) # no self connectivity

############### (2) E/I network ###############
import graph_analysis
nb_e = int(nb_hidden*0.8)
nb_i = nb_hidden - nb_e
ind_fromi = np.zeros((nb_hidden,nb_hidden),dtype=bool)
ind_fromi[nb_e:,:] = True # index of inhibitory neurons

wr, xy, cdens = graph_analysis.aij_distance2d([1000,1000], [250,150], nb_e, nb_i, np.array([[1,-1],[1,-1]]), cself=False, plot=False, randomseed=None)
wr = wr.T
wr *= 0.05 # scaling

plt.imshow(wr) # visualize initial weights

# %% [markdown]
# # Training (still debugging)

# %%
#%% compile (1st run numba is slow)
x_tmp, y1hot_tmp, y_tmp, cue_on_tmp = x[0,:,:,:].copy(),y1hot[0,:,:,:].copy(),y[0,:,:,:],cue_on.copy()
loss, out_rec, dw1, dwr, dw2, dbias, v_rec, z_rec, a_rec = snn_models.lif_eprop(w1,wr,w2,bias,B,x_tmp, y1hot_tmp, cue_on_tmp,decays)
print('compile done.')
print(out_rec[:,cue_on,:].shape)
batch_size = 39
pi = out_rec[:,cue_on,:]/np.exp(out_rec[:,cue_on,:]).sum(2).reshape(batch_size,dur_stim,1) 
pi_m = pi.mean(1)
(np.argmax(pi_m,axis=1) == y_tmp[:,cue_on][:,-1]).mean() 
# pi = np.exp(out_rec[:,cue_on,:])/np.exp(out_rec[:,cue_on,:]).sum(2).reshape(batch_size,dur_stim,1) 
# pi_m = pi.mean(1)
# (np.argmax(pi_m,axis=1) == y_batch[:,cue_on][:,-1]).mean()
# Out:
# compile done.
# (39, 1, 5)
# 0.1834319526627219

# %%
#%% run train
dw1_past = np.zeros((nb_inputs,nb_hidden))
dw2_past = np.zeros((nb_hidden,nb_outputs))
dwr_past = np.zeros((nb_hidden,nb_hidden))
dbias_past = np.zeros((nb_outputs,))
loss_train, fr_train, acc_train, spktr, wrs, atr, w1s, w2s, biases = [],[],[],[],[],[],[],[],[]
loss_valid, fr_valid, acc_valid = [],[],[]
n_epochs = 300

# Adam
m_t_w1 = np.zeros((nb_inputs,nb_hidden))
m_t_w2 = np.zeros((nb_hidden,nb_outputs))
m_t_wr = np.zeros((nb_hidden,nb_hidden))
m_t_bias = np.zeros((nb_outputs,))

v_t_w1 = np.zeros((nb_inputs,nb_hidden))
v_t_w2 = np.zeros((nb_hidden,nb_outputs))
v_t_wr = np.zeros((nb_hidden,nb_hidden))
v_t_bias = np.zeros((nb_outputs,))

b1 = 0.9
b2 = 0.999
alpha_lr = 0.002
eps = 1e-9

nb_batch = 2
for epoch in range(n_epochs): # 100
    ######################### train #########################
    loss_batch,acc_batch,fr_batch = np.zeros((nb_batch-1,)), np.zeros((nb_batch-1,)), np.zeros((nb_batch-1,))
    for batch_idx in range(nb_batch-1): # batch_idx = 0
        x_batch,y1hot_batch,y_batch = x[batch_idx],y1hot[batch_idx],y[batch_idx]
        loss, out_rec, dw1, dwr, dw2, dbias, v_rec, z_rec, a_rec = snn_models.lif_eprop(w1,wr,w2,bias,B,x_batch,y1hot_batch,cue_on,decays)

        # Adam
        # m_t_w1 = b1 * m_t_w1 + (1 - b1) / (-lr) * np.mean(dw1, 0)
        # m_t_w2 = b1 * m_t_w2 + (1 - b1) / (-lr) * np.mean(dw2, 0)
        # m_t_wr = b1 * m_t_wr + (1 - b1) / (-lr) * np.mean(dwr, 0)
        # m_t_bias = b1 * m_t_bias + (1 - b1) / (-lr) * np.mean(dbias, 0)

        # v_t_w1 = b2 * v_t_w1 + (1 - b2) / (lr**2) * np.power(np.mean(dw1, 0), 2)
        # v_t_w2 = b2 * v_t_w2 + (1 - b2) / (lr**2) * np.power(np.mean(dw2, 0), 2)
        # v_t_wr = b2 * v_t_wr + (1 - b2) / (lr**2) * np.power(np.mean(dwr, 0), 2)
        # v_t_bias = b2 * v_t_bias + (1 - b2) / (lr**2) * np.power(np.mean(dbias, 0), 2)

        # t = (epoch + 1)

        # m_w1_corr = m_t_w1 / (1. - b1**t)
        # m_w2_corr = m_t_w2 / (1. - b1**t)
        # m_wr_corr = m_t_wr / (1. - b1**t)
        # m_bias_corr = m_t_bias / (1. - b1**t)

        # v_w1_corr = v_t_w1 / (1. - b2**t)
        # v_w2_corr = v_t_w2 / (1. - b2**t)
        # v_wr_corr = v_t_wr / (1. - b2**t)
        # v_bias_corr = v_t_bias / (1. - b2**t)

        # div_w1 = -alpha_lr * m_w1_corr / (np.sqrt(v_w1_corr) + eps * np.ones_like(v_w1_corr))
        # div_w2 = -alpha_lr * m_w2_corr / (np.sqrt(v_w2_corr) + eps * np.ones_like(v_w2_corr))
        # div_wr = -alpha_lr * m_wr_corr / (np.sqrt(v_wr_corr) + eps * np.ones_like(v_wr_corr))
        # div_bias = -alpha_lr * m_bias_corr / (np.sqrt(v_bias_corr) + eps * np.ones_like(v_bias_corr))

        # w1 += div_w1 # input-->hidden update
        # w2 += div_w2 # hidden-->hidden update
        # wr += div_wr # hidden-->output update
        # bias += div_bias # bias update

        # Momemtum
        dw1_past = 0.9*dw1_past + np.mean(dw1,0) #!!! momentum=0.9
        dw2_past = 0.9*dw2_past + np.mean(dw2,0) #!!! momentum=0.9
        dwr_past = 0.9*dwr_past + np.mean(dwr,0) #!!! momentum=0.9
        dbias_past = 0.9*dbias_past + np.mean(dbias,0) #!!! momentum=0.9 #AKSHAY
        
        w1 += dw1_past # input-->hidden update
        w2 += dw2_past # hidden-->hidden update
        wr += dwr_past # hidden-->output update
        bias += dbias_past # bias update #AKSHAY
        
        # w1 += np.mean(dw1,0) # these are for no-momentum update (slow learning)
        # w2 += np.mean(dw2,0)
        # wr += np.mean(dwr,0)
        # bias += np.mean(dbias,0)
        # np.fill_diagonal(wr,0) # no-self connectivity

        #!!! below 5 lines are valid only for E/I network (uncomment when using random network) 
        ind_negative = wr<0
        ind = ind_negative*(~ind_fromi) # find negative & exciatory neurons
        wr[ind] = 0. # force the negative weights to 0
        ind = (~ind_negative)*ind_fromi # find positive & inhibitory neurons
        wr[ind] = 0. # force the positive weights to 0
        
        pi = np.exp(out_rec[:,cue_on,:])/np.exp(out_rec[:,cue_on,:]).sum(2).reshape(batch_size,dur_stim,1) # sfotmax /// [batch_size,dur_stim,2]
        pi_m = pi.mean(1)
        acc_batch[batch_idx] = (np.argmax(pi_m,axis=1) == y_batch[:,cue_on][:,-1]).mean() # save cc
        
        loss_batch[batch_idx] = loss.mean() # save loss
        fr_batch[batch_idx] = 1000*z_rec.mean() # save firing rate
        
    loss_train.append(loss_batch.mean()) # save loss 
    acc_train.append(acc_batch.mean()) # save acc
    fr_train.append(fr_batch.mean()) # save firing rate
    print('EPOCH %d TRAIN) loss: %0.4f, acc: %0.4f, fr: %0.4f Hz' %(epoch, loss_train[epoch], acc_train[epoch], fr_train[epoch]))

    ######################### validate #########################
    x_batch,y1hot_batch,y_batch = x[-1],y1hot[-1],y[-1] # the last batch is for valid data
    loss, out_rec, dw1, dwr, dw2, dbias, v_rec, z_rec, a_rec = snn_models.lif_eprop(w1,wr,w2,bias,B,x_batch,y1hot_batch,cue_on,decays)
    
    
    pi = np.exp(out_rec[:,cue_on,:])/np.exp(out_rec[:,cue_on,:]).sum(2).reshape(batch_size,dur_stim,1) # softmax /// [batch_size,dur_stim,2]
    pi_m = pi.mean(1)
    acc_valid.append((np.argmax(pi_m,axis=1) == y_batch[:,cue_on][:,-1]).mean()) # save acc
    
    loss_valid.append(loss.mean()) # save loss
    fr_valid.append(1000*z_rec.mean()) # save firing rate
    print('EPOCH %d VALID) loss: %0.4f, acc: %0.4f, fr: %0.4f Hz' %(epoch, loss_valid[epoch], acc_valid[epoch], fr_valid[epoch]))
        
    spktr.append(z_rec[0]) # save spike train /// save one batch data only to save memory
    atr.append(a_rec[0]) # save a trace
    wrs.append(wr.copy()) # save weights
    w1s.append(w1.copy()) # save weights
    w2s.append(w2.copy()) # save weights
    biases.append(bias.copy()) # save weights
    
    ######################### save best weights #########################
    # if loss_valid[-1] == min(loss_valid): # or you can use acc criteria instead
    if acc_valid[-1] == max(acc_valid): # or you can use acc criteria instead
        w1_save,w2_save,wr_save,bias_save = w1.copy(),w2.copy(),wr.copy(),bias.copy()
        epoch_best = epoch
    
# ######################### save best model ########################## never mind!!!
# epoch_best = acc_valid.index(max(acc_valid))
# acc_save = acc_valid[epoch_best]
# w1_save, w2_save, wr_save, bias_save = w1s[epoch_best].copy(), w2[epoch_best].copy(), wr[epoch_best].copy(), bias[epoch_best].copy()
print('EPOCH BEST %d VALID) loss: %0.4f, acc: %0.4f, fr: %0.4f Hz' %(epoch_best, loss_valid[epoch_best], acc_valid[epoch_best], fr_valid[epoch_best]))
    
spktr = np.stack(spktr,0)
atr = np.stack(atr,0)
wrs = np.stack(wrs,0)
N = int(n_epochs/8) # epoch interval for plotting
# Out:
# 5905, acc: 0.1959, fr: 9.1795 Hz
# EPOCH 130 TRAIN) loss: 1.5905, acc: 0.1959, fr: 9.1795 Hz
# EPOCH 130 VALID) loss: 1.5921, acc: 0.1946, fr: 9.2179 Hz
# EPOCH 131 TRAIN) loss: 1.5921, acc: 0.1946, fr: 9.2179 Hz
# EPOCH 131 VALID) loss: 1.5929, acc: 0.1946, fr: 9.2077 Hz
# EPOCH 132 TRAIN) loss: 1.5929, acc: 0.1946, fr: 9.2077 Hz
# EPOCH 132 VALID) loss: 1.5876, acc: 0.1966, fr: 9.1590 Hz
# EPOCH 133 TRAIN) loss: 1.5876, acc: 0.1966, fr: 9.1590 Hz
# EPOCH 133 VALID) loss: 1.5857, acc: 0.1953, fr: 9.2000 Hz
# EPOCH 134 TRAIN) loss: 1.5857, acc: 0.1953, fr: 9.2000 Hz
# EPOCH 134 VALID) loss: 1.5852, acc: 0.1946, fr: 9.2000 Hz
# EPOCH 135 TRAIN) loss: 1.5852, acc: 0.1946, fr: 9.2000 Hz
# EPOCH 135 VALID) loss: 1.5843, acc: 0.1946, fr: 9.2231 Hz
# EPOCH 136 TRAIN) loss: 1.5843, acc: 0.1946, fr: 9.2231 Hz
# EPOCH 136 VALID) loss: 1.5836, acc: 0.1946, fr: 9.1923 Hz
# EPOCH 137 TRAIN) loss: 1.5836, acc: 0.1946, fr: 9.1923 Hz
# EPOCH 137 VALID) loss: 1.5833, acc: 0.1946, fr: 9.2308 Hz
# EPOCH 138 TRAIN) loss: 1.5833, acc: 0.1946, fr: 9.2308 Hz
# EPOCH 138 VALID) loss: 1.5824, acc: 0.1946, fr: 9.2179 Hz
# EPOCH 139 TRAIN) loss: 1.5824, acc: 0.1946, fr: 9.2179 Hz
# EPOCH 139 VALID) loss: 1.5839, acc: 0.1946, fr: 9.2231 Hz
# EPOCH 140 TRAIN) loss: 1.5839, acc: 0.1946, fr: 9.2231 Hz
# EPOCH 140 VALID) loss: 1.5856, acc: 0.1966, fr: 9.1846 Hz
# EPOCH 141 TRAIN) loss: 1.5856, acc: 0.1966, fr: 9.1846 Hz
# EPOCH 141 VALID) loss: 1.5858, acc: 0.1966, fr: 9.1692 Hz
# EPOCH 142 TRAIN) loss: 1.5858, acc: 0.1966, fr: 9.1692 Hz
# EPOCH 142 VALID) loss: 1.5930, acc: 0.1979, fr: 9.2256 Hz
# EPOCH 143 TRAIN) loss: 1.5930, acc: 0.1979, fr: 9.2256 Hz
# EPOCH 143 VALID) loss: 1.5929, acc: 0.1966, fr: 9.2769 Hz
# EPOCH 144 TRAIN) loss: 1.5929, acc: 0.1966, fr: 9.2769 Hz
# EPOCH 144 VALID) loss: 1.5878, acc: 0.1966, fr: 9.2590 Hz
# EPOCH 145 TRAIN) loss: 1.5878, acc: 0.1966, fr: 9.2590 Hz
# EPOCH 145 VALID) loss: 1.5873, acc: 0.1966, fr: 9.2897 Hz
# EPOCH 146 TRAIN) loss: 1.5873, acc: 0.1966, fr: 9.2897 Hz
# EPOCH 146 VALID) loss: 1.5805, acc: 0.1972, fr: 9.3256 Hz
# EPOCH 147 TRAIN) loss: 1.5805, acc: 0.1972, fr: 9.3256 Hz
# EPOCH 147 VALID) loss: 1.5897, acc: 0.1972, fr: 9.3333 Hz
# EPOCH 148 TRAIN) loss: 1.5897, acc: 0.1972, fr: 9.3333 Hz
# EPOCH 148 VALID) loss: 1.5877, acc: 0.1979, fr: 9.3718 Hz
# EPOCH 149 TRAIN) loss: 1.5877, acc: 0.1979, fr: 9.3718 Hz
# EPOCH 149 VALID) loss: 1.5927, acc: 0.1979, fr: 9.4026 Hz
# EPOCH 150 TRAIN) loss: 1.5927, acc: 0.1979, fr: 9.4026 Hz
# EPOCH 150 VALID) loss: 1.5934, acc: 0.1959, fr: 9.4205 Hz
# EPOCH 151 TRAIN) loss: 1.5934, acc: 0.1959, fr: 9.4205 Hz
# EPOCH 151 VALID) loss: 1.5864, acc: 0.1966, fr: 9.3897 Hz
# EPOCH 152 TRAIN) loss: 1.5864, acc: 0.1966, fr: 9.3897 Hz
# EPOCH 152 VALID) loss: 1.5862, acc: 0.1966, fr: 9.4026 Hz
# EPOCH 153 TRAIN) loss: 1.5862, acc: 0.1966, fr: 9.4026 Hz
# EPOCH 153 VALID) loss: 1.5904, acc: 0.1913, fr: 9.4282 Hz
# EPOCH 154 TRAIN) loss: 1.5904, acc: 0.1913, fr: 9.4282 Hz
# EPOCH 154 VALID) loss: 1.5886, acc: 0.1913, fr: 9.4487 Hz
# EPOCH 155 TRAIN) loss: 1.5886, acc: 0.1913, fr: 9.4487 Hz
# EPOCH 155 VALID) loss: 1.5917, acc: 0.1926, fr: 9.5051 Hz
# EPOCH 156 TRAIN) loss: 1.5917, acc: 0.1926, fr: 9.5051 Hz
# EPOCH 156 VALID) loss: 1.5904, acc: 0.1920, fr: 9.4949 Hz
# EPOCH 157 TRAIN) loss: 1.5904, acc: 0.1920, fr: 9.4949 Hz
# EPOCH 157 VALID) loss: 1.5949, acc: 0.1920, fr: 9.4821 Hz
# EPOCH 158 TRAIN) loss: 1.5949, acc: 0.1920, fr: 9.4821 Hz
# EPOCH 158 VALID) loss: 1.5839, acc: 0.1933, fr: 9.4846 Hz
# EPOCH 159 TRAIN) loss: 1.5839, acc: 0.1933, fr: 9.4846 Hz
# EPOCH 159 VALID) loss: 1.5819, acc: 0.1972, fr: 9.4949 Hz
# EPOCH 160 TRAIN) loss: 1.5819, acc: 0.1972, fr: 9.4949 Hz
# EPOCH 160 VALID) loss: 1.5775, acc: 0.1966, fr: 9.5000 Hz
# EPOCH 161 TRAIN) loss: 1.5775, acc: 0.1966, fr: 9.5000 Hz
# EPOCH 161 VALID) loss: 1.5852, acc: 0.1966, fr: 9.4872 Hz
# EPOCH 162 TRAIN) loss: 1.5852, acc: 0.1966, fr: 9.4872 Hz
# EPOCH 162 VALID) loss: 1.5854, acc: 0.1966, fr: 9.5103 Hz
# EPOCH 163 TRAIN) loss: 1.5854, acc: 0.1966, fr: 9.5103 Hz
# EPOCH 163 VALID) loss: 1.5834, acc: 0.1979, fr: 9.5179 Hz
# EPOCH 164 TRAIN) loss: 1.5834, acc: 0.1979, fr: 9.5179 Hz
# EPOCH 164 VALID) loss: 1.5830, acc: 0.1972, fr: 9.5231 Hz
# EPOCH 165 TRAIN) loss: 1.5830, acc: 0.1972, fr: 9.5231 Hz
# EPOCH 165 VALID) loss: 1.5858, acc: 0.1972, fr: 9.5308 Hz
# EPOCH 166 TRAIN) loss: 1.5858, acc: 0.1972, fr: 9.5308 Hz
# EPOCH 166 VALID) loss: 1.5854, acc: 0.1979, fr: 9.5436 Hz
# EPOCH 167 TRAIN) loss: 1.5854, acc: 0.1979, fr: 9.5436 Hz
# EPOCH 167 VALID) loss: 1.5850, acc: 0.1986, fr: 9.5564 Hz
# EPOCH 168 TRAIN) loss: 1.5850, acc: 0.1986, fr: 9.5564 Hz
# EPOCH 168 VALID) loss: 1.5832, acc: 0.1986, fr: 9.5487 Hz
# EPOCH 169 TRAIN) loss: 1.5832, acc: 0.1986, fr: 9.5487 Hz
# EPOCH 169 VALID) loss: 1.5851, acc: 0.1986, fr: 9.5513 Hz
# EPOCH 170 TRAIN) loss: 1.5851, acc: 0.1986, fr: 9.5513 Hz
# EPOCH 170 VALID) loss: 1.5785, acc: 0.1999, fr: 9.5026 Hz
# EPOCH 171 TRAIN) loss: 1.5785, acc: 0.1999, fr: 9.5026 Hz
# EPOCH 171 VALID) loss: 1.5777, acc: 0.2005, fr: 9.5692 Hz
# EPOCH 172 TRAIN) loss: 1.5777, acc: 0.2005, fr: 9.5692 Hz
# EPOCH 172 VALID) loss: 1.5765, acc: 0.1999, fr: 9.5897 Hz
# EPOCH 173 TRAIN) loss: 1.5765, acc: 0.1999, fr: 9.5897 Hz
# EPOCH 173 VALID) loss: 1.5726, acc: 0.1999, fr: 9.5821 Hz
# EPOCH 174 TRAIN) loss: 1.5726, acc: 0.1999, fr: 9.5821 Hz
# EPOCH 174 VALID) loss: 1.5725, acc: 0.1992, fr: 9.5795 Hz
# EPOCH 175 TRAIN) loss: 1.5725, acc: 0.1992, fr: 9.5795 Hz
# EPOCH 175 VALID) loss: 1.5745, acc: 0.1946, fr: 9.5846 Hz
# EPOCH 176 TRAIN) loss: 1.5745, acc: 0.1946, fr: 9.5846 Hz
# EPOCH 176 VALID) loss: 1.5740, acc: 0.1999, fr: 9.6026 Hz
# EPOCH 177 TRAIN) loss: 1.5740, acc: 0.1999, fr: 9.6026 Hz
# EPOCH 177 VALID) loss: 1.5785, acc: 0.2005, fr: 9.5923 Hz
# EPOCH 178 TRAIN) loss: 1.5785, acc: 0.2005, fr: 9.5923 Hz
# EPOCH 178 VALID) loss: 1.5815, acc: 0.1992, fr: 9.6231 Hz
# EPOCH 179 TRAIN) loss: 1.5815, acc: 0.1992, fr: 9.6231 Hz
# EPOCH 179 VALID) loss: 1.5794, acc: 0.1992, fr: 9.6231 Hz
# EPOCH 180 TRAIN) loss: 1.5794, acc: 0.1992, fr: 9.6231 Hz
# EPOCH 180 VALID) loss: 1.5788, acc: 0.1999, fr: 9.6103 Hz
# EPOCH 181 TRAIN) loss: 1.5788, acc: 0.1999, fr: 9.6103 Hz
# EPOCH 181 VALID) loss: 1.5783, acc: 0.1999, fr: 9.6205 Hz
# EPOCH 182 TRAIN) loss: 1.5783, acc: 0.1999, fr: 9.6205 Hz
# EPOCH 182 VALID) loss: 1.5810, acc: 0.1999, fr: 9.6564 Hz
# EPOCH 183 TRAIN) loss: 1.5810, acc: 0.1999, fr: 9.6564 Hz
# EPOCH 183 VALID) loss: 1.5801, acc: 0.1992, fr: 9.6949 Hz
# EPOCH 184 TRAIN) loss: 1.5801, acc: 0.1992, fr: 9.6949 Hz
# EPOCH 184 VALID) loss: 1.5786, acc: 0.1986, fr: 9.7051 Hz
# EPOCH 185 TRAIN) loss: 1.5786, acc: 0.1986, fr: 9.7051 Hz
# EPOCH 185 VALID) loss: 1.5755, acc: 0.1986, fr: 9.7385 Hz
# EPOCH 186 TRAIN) loss: 1.5755, acc: 0.1986, fr: 9.7385 Hz
# EPOCH 186 VALID) loss: 1.5756, acc: 0.1986, fr: 9.7359 Hz
# EPOCH 187 TRAIN) loss: 1.5756, acc: 0.1986, fr: 9.7359 Hz
# EPOCH 187 VALID) loss: 1.5772, acc: 0.1986, fr: 9.7667 Hz
# EPOCH 188 TRAIN) loss: 1.5772, acc: 0.1986, fr: 9.7667 Hz
# EPOCH 188 VALID) loss: 1.5743, acc: 0.1986, fr: 9.7744 Hz
# EPOCH 189 TRAIN) loss: 1.5743, acc: 0.1986, fr: 9.7744 Hz
# EPOCH 189 VALID) loss: 1.5753, acc: 0.1979, fr: 9.7179 Hz
# EPOCH 190 TRAIN) loss: 1.5753, acc: 0.1979, fr: 9.7179 Hz
# EPOCH 190 VALID) loss: 1.5741, acc: 0.1986, fr: 9.7359 Hz
# EPOCH 191 TRAIN) loss: 1.5741, acc: 0.1986, fr: 9.7359 Hz
# EPOCH 191 VALID) loss: 1.5727, acc: 0.1979, fr: 9.7410 Hz
# EPOCH 192 TRAIN) loss: 1.5727, acc: 0.1979, fr: 9.7410 Hz
# EPOCH 192 VALID) loss: 1.5795, acc: 0.1986, fr: 9.7795 Hz
# EPOCH 193 TRAIN) loss: 1.5795, acc: 0.1986, fr: 9.7795 Hz
# EPOCH 193 VALID) loss: 1.5794, acc: 0.1986, fr: 9.8077 Hz
# EPOCH 194 TRAIN) loss: 1.5794, acc: 0.1986, fr: 9.8077 Hz
# EPOCH 194 VALID) loss: 1.5685, acc: 0.1933, fr: 9.8462 Hz
# EPOCH 195 TRAIN) loss: 1.5685, acc: 0.1933, fr: 9.8462 Hz
# EPOCH 195 VALID) loss: 1.5700, acc: 0.1893, fr: 9.8897 Hz
# EPOCH 196 TRAIN) loss: 1.5700, acc: 0.1893, fr: 9.8897 Hz
# EPOCH 196 VALID) loss: 1.5666, acc: 0.1900, fr: 9.8872 Hz
# EPOCH 197 TRAIN) loss: 1.5666, acc: 0.1900, fr: 9.8872 Hz
# EPOCH 197 VALID) loss: 1.5668, acc: 0.1893, fr: 9.8821 Hz
# EPOCH 198 TRAIN) loss: 1.5668, acc: 0.1893, fr: 9.8821 Hz
# EPOCH 198 VALID) loss: 1.5643, acc: 0.1893, fr: 9.8949 Hz
# EPOCH 199 TRAIN) loss: 1.5643, acc: 0.1893, fr: 9.8949 Hz
# EPOCH 199 VALID) loss: 1.5622, acc: 0.1887, fr: 9.8949 Hz
# EPOCH 200 TRAIN) loss: 1.5622, acc: 0.1887, fr: 9.8949 Hz
# EPOCH 200 VALID) loss: 1.5602, acc: 0.1900, fr: 9.9103 Hz
# EPOCH 201 TRAIN) loss: 1.5602, acc: 0.1900, fr: 9.9103 Hz
# EPOCH 201 VALID) loss: 1.5588, acc: 0.1900, fr: 9.9000 Hz
# EPOCH 202 TRAIN) loss: 1.5588, acc: 0.1900, fr: 9.9000 Hz
# EPOCH 202 VALID) loss: 1.5660, acc: 0.1900, fr: 9.9103 Hz
# EPOCH 203 TRAIN) loss: 1.5660, acc: 0.1900, fr: 9.9103 Hz
# EPOCH 203 VALID) loss: 1.5651, acc: 0.1940, fr: 9.9385 Hz
# EPOCH 204 TRAIN) loss: 1.5651, acc: 0.1940, fr: 9.9385 Hz
# EPOCH 204 VALID) loss: 1.5637, acc: 0.1946, fr: 9.9590 Hz
# EPOCH 205 TRAIN) loss: 1.5637, acc: 0.1946, fr: 9.9590 Hz
# EPOCH 205 VALID) loss: 1.5659, acc: 0.1946, fr: 9.9615 Hz
# EPOCH 206 TRAIN) loss: 1.5659, acc: 0.1946, fr: 9.9615 Hz
# EPOCH 206 VALID) loss: 1.5667, acc: 0.1887, fr: 9.9744 Hz
# EPOCH 207 TRAIN) loss: 1.5667, acc: 0.1887, fr: 9.9744 Hz
# EPOCH 207 VALID) loss: 1.5682, acc: 0.1940, fr: 9.9615 Hz
# EPOCH 208 TRAIN) loss: 1.5682, acc: 0.1940, fr: 9.9615 Hz
# EPOCH 208 VALID) loss: 1.5702, acc: 0.1940, fr: 10.0051 Hz
# EPOCH 209 TRAIN) loss: 1.5702, acc: 0.1940, fr: 10.0051 Hz
# EPOCH 209 VALID) loss: 1.5710, acc: 0.1940, fr: 10.0436 Hz
# EPOCH 210 TRAIN) loss: 1.5710, acc: 0.1940, fr: 10.0436 Hz
# EPOCH 210 VALID) loss: 1.5697, acc: 0.1940, fr: 10.0333 Hz
# EPOCH 211 TRAIN) loss: 1.5697, acc: 0.1940, fr: 10.0333 Hz
# EPOCH 211 VALID) loss: 1.5653, acc: 0.1986, fr: 10.0462 Hz
# EPOCH 212 TRAIN) loss: 1.5653, acc: 0.1986, fr: 10.0462 Hz
# EPOCH 212 VALID) loss: 1.5644, acc: 0.1992, fr: 10.0410 Hz
# EPOCH 213 TRAIN) loss: 1.5644, acc: 0.1992, fr: 10.0410 Hz
# EPOCH 213 VALID) loss: 1.5617, acc: 0.1992, fr: 10.0462 Hz
# EPOCH 214 TRAIN) loss: 1.5617, acc: 0.1992, fr: 10.0462 Hz
# EPOCH 214 VALID) loss: 1.5602, acc: 0.1992, fr: 10.0692 Hz
# EPOCH 215 TRAIN) loss: 1.5602, acc: 0.1992, fr: 10.0692 Hz
# EPOCH 215 VALID) loss: 1.5582, acc: 0.1992, fr: 10.0590 Hz
# EPOCH 216 TRAIN) loss: 1.5582, acc: 0.1992, fr: 10.0590 Hz
# EPOCH 216 VALID) loss: 1.5576, acc: 0.1999, fr: 10.0538 Hz
# EPOCH 217 TRAIN) loss: 1.5576, acc: 0.1999, fr: 10.0538 Hz
# EPOCH 217 VALID) loss: 1.5533, acc: 0.1999, fr: 10.0564 Hz
# EPOCH 218 TRAIN) loss: 1.5533, acc: 0.1999, fr: 10.0564 Hz
# EPOCH 218 VALID) loss: 1.5523, acc: 0.1986, fr: 10.0718 Hz
# EPOCH 219 TRAIN) loss: 1.5523, acc: 0.1986, fr: 10.0718 Hz
# EPOCH 219 VALID) loss: 1.5548, acc: 0.1986, fr: 10.0846 Hz
# EPOCH 220 TRAIN) loss: 1.5548, acc: 0.1986, fr: 10.0846 Hz
# EPOCH 220 VALID) loss: 1.5535, acc: 0.1992, fr: 10.1231 Hz
# EPOCH 221 TRAIN) loss: 1.5535, acc: 0.1992, fr: 10.1231 Hz
# EPOCH 221 VALID) loss: 1.5532, acc: 0.1992, fr: 10.1231 Hz
# EPOCH 222 TRAIN) loss: 1.5532, acc: 0.1992, fr: 10.1231 Hz
# EPOCH 222 VALID) loss: 1.5552, acc: 0.1992, fr: 10.1487 Hz
# EPOCH 223 TRAIN) loss: 1.5552, acc: 0.1992, fr: 10.1487 Hz
# EPOCH 223 VALID) loss: 1.5519, acc: 0.1999, fr: 10.1846 Hz
# EPOCH 224 TRAIN) loss: 1.5519, acc: 0.1999, fr: 10.1846 Hz
# EPOCH 224 VALID) loss: 1.5523, acc: 0.1992, fr: 10.1385 Hz
# EPOCH 225 TRAIN) loss: 1.5523, acc: 0.1992, fr: 10.1385 Hz
# EPOCH 225 VALID) loss: 1.5482, acc: 0.2005, fr: 10.1974 Hz
# EPOCH 226 TRAIN) loss: 1.5482, acc: 0.2005, fr: 10.1974 Hz
# EPOCH 226 VALID) loss: 1.5489, acc: 0.2005, fr: 10.1692 Hz
# EPOCH 227 TRAIN) loss: 1.5489, acc: 0.2005, fr: 10.1692 Hz
# EPOCH 227 VALID) loss: 1.5486, acc: 0.2005, fr: 10.1769 Hz
# EPOCH 228 TRAIN) loss: 1.5486, acc: 0.2005, fr: 10.1769 Hz
# EPOCH 228 VALID) loss: 1.5472, acc: 0.1992, fr: 10.1872 Hz
# EPOCH 229 TRAIN) loss: 1.5472, acc: 0.1992, fr: 10.1872 Hz
# EPOCH 229 VALID) loss: 1.5439, acc: 0.1999, fr: 10.2051 Hz
# EPOCH 230 TRAIN) loss: 1.5439, acc: 0.1999, fr: 10.2051 Hz
# EPOCH 230 VALID) loss: 1.5467, acc: 0.1999, fr: 10.2154 Hz
# EPOCH 231 TRAIN) loss: 1.5467, acc: 0.1999, fr: 10.2154 Hz
# EPOCH 231 VALID) loss: 1.5443, acc: 0.1999, fr: 10.1769 Hz
# EPOCH 232 TRAIN) loss: 1.5443, acc: 0.1999, fr: 10.1769 Hz
# EPOCH 232 VALID) loss: 1.5464, acc: 0.1999, fr: 10.2077 Hz
# EPOCH 233 TRAIN) loss: 1.5464, acc: 0.1999, fr: 10.2077 Hz
# EPOCH 233 VALID) loss: 1.5459, acc: 0.1999, fr: 10.1923 Hz
# EPOCH 234 TRAIN) loss: 1.5459, acc: 0.1999, fr: 10.1923 Hz
# EPOCH 234 VALID) loss: 1.5471, acc: 0.1999, fr: 10.1949 Hz
# EPOCH 235 TRAIN) loss: 1.5471, acc: 0.1999, fr: 10.1949 Hz
# EPOCH 235 VALID) loss: 1.5437, acc: 0.1999, fr: 10.2462 Hz
# EPOCH 236 TRAIN) loss: 1.5437, acc: 0.1999, fr: 10.2462 Hz
# EPOCH 236 VALID) loss: 1.5439, acc: 0.1999, fr: 10.2590 Hz
# EPOCH 237 TRAIN) loss: 1.5439, acc: 0.1999, fr: 10.2590 Hz
# EPOCH 237 VALID) loss: 1.5458, acc: 0.1999, fr: 10.2513 Hz
# EPOCH 238 TRAIN) loss: 1.5458, acc: 0.1999, fr: 10.2513 Hz
# EPOCH 238 VALID) loss: 1.5467, acc: 0.1992, fr: 10.2462 Hz
# EPOCH 239 TRAIN) loss: 1.5467, acc: 0.1992, fr: 10.2462 Hz
# EPOCH 239 VALID) loss: 1.5440, acc: 0.1992, fr: 10.2615 Hz
# EPOCH 240 TRAIN) loss: 1.5440, acc: 0.1992, fr: 10.2615 Hz
# EPOCH 240 VALID) loss: 1.5430, acc: 0.1992, fr: 10.2923 Hz
# EPOCH 241 TRAIN) loss: 1.5430, acc: 0.1992, fr: 10.2923 Hz
# EPOCH 241 VALID) loss: 1.5418, acc: 0.1999, fr: 10.3128 Hz
# EPOCH 242 TRAIN) loss: 1.5418, acc: 0.1999, fr: 10.3128 Hz
# EPOCH 242 VALID) loss: 1.5322, acc: 0.1999, fr: 10.3667 Hz
# EPOCH 243 TRAIN) loss: 1.5322, acc: 0.1999, fr: 10.3667 Hz
# EPOCH 243 VALID) loss: 1.5327, acc: 0.1999, fr: 10.3974 Hz
# EPOCH 244 TRAIN) loss: 1.5327, acc: 0.1999, fr: 10.3974 Hz
# EPOCH 244 VALID) loss: 1.5294, acc: 0.1999, fr: 10.4538 Hz
# EPOCH 245 TRAIN) loss: 1.5294, acc: 0.1999, fr: 10.4538 Hz
# EPOCH 245 VALID) loss: 1.5273, acc: 0.1999, fr: 10.4410 Hz
# EPOCH 246 TRAIN) loss: 1.5273, acc: 0.1999, fr: 10.4410 Hz
# EPOCH 246 VALID) loss: 1.5370, acc: 0.1999, fr: 10.4436 Hz
# EPOCH 247 TRAIN) loss: 1.5370, acc: 0.1999, fr: 10.4436 Hz
# EPOCH 247 VALID) loss: 1.5362, acc: 0.1999, fr: 10.4487 Hz
# EPOCH 248 TRAIN) loss: 1.5362, acc: 0.1999, fr: 10.4487 Hz
# EPOCH 248 VALID) loss: 1.5356, acc: 0.1999, fr: 10.4513 Hz
# EPOCH 249 TRAIN) loss: 1.5356, acc: 0.1999, fr: 10.4513 Hz
# EPOCH 249 VALID) loss: 1.5361, acc: 0.1999, fr: 10.4744 Hz
# EPOCH 250 TRAIN) loss: 1.5361, acc: 0.1999, fr: 10.4744 Hz
# EPOCH 250 VALID) loss: 1.5425, acc: 0.1986, fr: 10.4667 Hz
# EPOCH 251 TRAIN) loss: 1.5425, acc: 0.1986, fr: 10.4667 Hz
# EPOCH 251 VALID) loss: 1.5406, acc: 0.1979, fr: 10.4231 Hz
# EPOCH 252 TRAIN) loss: 1.5406, acc: 0.1979, fr: 10.4231 Hz
# EPOCH 252 VALID) loss: 1.5389, acc: 0.1979, fr: 10.4077 Hz
# EPOCH 253 TRAIN) loss: 1.5389, acc: 0.1979, fr: 10.4077 Hz
# EPOCH 253 VALID) loss: 1.5365, acc: 0.1986, fr: 10.4179 Hz
# EPOCH 254 TRAIN) loss: 1.5365, acc: 0.1986, fr: 10.4179 Hz
# EPOCH 254 VALID) loss: 1.5400, acc: 0.1992, fr: 10.4103 Hz
# EPOCH 255 TRAIN) loss: 1.5400, acc: 0.1992, fr: 10.4103 Hz
# EPOCH 255 VALID) loss: 1.5368, acc: 0.1999, fr: 10.3897 Hz
# EPOCH 256 TRAIN) loss: 1.5368, acc: 0.1999, fr: 10.3897 Hz
# EPOCH 256 VALID) loss: 1.5358, acc: 0.1946, fr: 10.4000 Hz
# EPOCH 257 TRAIN) loss: 1.5358, acc: 0.1946, fr: 10.4000 Hz
# EPOCH 257 VALID) loss: 1.5359, acc: 0.1940, fr: 10.3897 Hz
# EPOCH 258 TRAIN) loss: 1.5359, acc: 0.1940, fr: 10.3897 Hz
# EPOCH 258 VALID) loss: 1.5348, acc: 0.1992, fr: 10.3949 Hz
# EPOCH 259 TRAIN) loss: 1.5348, acc: 0.1992, fr: 10.3949 Hz
# EPOCH 259 VALID) loss: 1.5320, acc: 0.1992, fr: 10.3744 Hz
# EPOCH 260 TRAIN) loss: 1.5320, acc: 0.1992, fr: 10.3744 Hz
# EPOCH 260 VALID) loss: 1.5322, acc: 0.1999, fr: 10.4026 Hz
# EPOCH 261 TRAIN) loss: 1.5322, acc: 0.1999, fr: 10.4026 Hz
# EPOCH 261 VALID) loss: 1.5302, acc: 0.1953, fr: 10.4179 Hz
# EPOCH 262 TRAIN) loss: 1.5302, acc: 0.1953, fr: 10.4179 Hz
# EPOCH 262 VALID) loss: 1.5307, acc: 0.1946, fr: 10.4103 Hz
# EPOCH 263 TRAIN) loss: 1.5307, acc: 0.1946, fr: 10.4103 Hz
# EPOCH 263 VALID) loss: 1.5299, acc: 0.1940, fr: 10.4026 Hz
# EPOCH 264 TRAIN) loss: 1.5299, acc: 0.1940, fr: 10.4026 Hz
# EPOCH 264 VALID) loss: 1.5317, acc: 0.1946, fr: 10.4667 Hz
# EPOCH 265 TRAIN) loss: 1.5317, acc: 0.1946, fr: 10.4667 Hz
# EPOCH 265 VALID) loss: 1.5280, acc: 0.1946, fr: 10.4564 Hz
# EPOCH 266 TRAIN) loss: 1.5280, acc: 0.1946, fr: 10.4564 Hz
# EPOCH 266 VALID) loss: 1.5344, acc: 0.1946, fr: 10.4821 Hz
# EPOCH 267 TRAIN) loss: 1.5344, acc: 0.1946, fr: 10.4821 Hz
# EPOCH 267 VALID) loss: 1.5308, acc: 0.1900, fr: 10.4769 Hz
# EPOCH 268 TRAIN) loss: 1.5308, acc: 0.1900, fr: 10.4769 Hz
# EPOCH 268 VALID) loss: 1.5317, acc: 0.1900, fr: 10.4513 Hz
# EPOCH 269 TRAIN) loss: 1.5317, acc: 0.1900, fr: 10.4513 Hz
# EPOCH 269 VALID) loss: 1.5316, acc: 0.1900, fr: 10.4667 Hz
# EPOCH 270 TRAIN) loss: 1.5316, acc: 0.1900, fr: 10.4667 Hz
# EPOCH 270 VALID) loss: 1.5261, acc: 0.1900, fr: 10.5077 Hz
# EPOCH 271 TRAIN) loss: 1.5261, acc: 0.1900, fr: 10.5077 Hz
# EPOCH 271 VALID) loss: 1.5258, acc: 0.1900, fr: 10.5538 Hz
# EPOCH 272 TRAIN) loss: 1.5258, acc: 0.1900, fr: 10.5538 Hz
# EPOCH 272 VALID) loss: 1.5261, acc: 0.1900, fr: 10.5436 Hz
# EPOCH 273 TRAIN) loss: 1.5261, acc: 0.1900, fr: 10.5436 Hz
# EPOCH 273 VALID) loss: 1.5261, acc: 0.1893, fr: 10.5590 Hz
# EPOCH 274 TRAIN) loss: 1.5261, acc: 0.1893, fr: 10.5590 Hz
# EPOCH 274 VALID) loss: 1.5294, acc: 0.1893, fr: 10.5487 Hz
# EPOCH 275 TRAIN) loss: 1.5294, acc: 0.1893, fr: 10.5487 Hz
# EPOCH 275 VALID) loss: 1.5307, acc: 0.1940, fr: 10.5667 Hz
# EPOCH 276 TRAIN) loss: 1.5307, acc: 0.1940, fr: 10.5667 Hz
# EPOCH 276 VALID) loss: 1.5300, acc: 0.1940, fr: 10.5974 Hz
# EPOCH 277 TRAIN) loss: 1.5300, acc: 0.1940, fr: 10.5974 Hz
# EPOCH 277 VALID) loss: 1.5302, acc: 0.1940, fr: 10.6000 Hz
# EPOCH 278 TRAIN) loss: 1.5302, acc: 0.1940, fr: 10.6000 Hz
# EPOCH 278 VALID) loss: 1.5290, acc: 0.1940, fr: 10.6282 Hz
# EPOCH 279 TRAIN) loss: 1.5290, acc: 0.1940, fr: 10.6282 Hz
# EPOCH 279 VALID) loss: 1.5316, acc: 0.1946, fr: 10.5949 Hz
# EPOCH 280 TRAIN) loss: 1.5316, acc: 0.1946, fr: 10.5949 Hz
# EPOCH 280 VALID) loss: 1.5310, acc: 0.1940, fr: 10.5795 Hz
# EPOCH 281 TRAIN) loss: 1.5310, acc: 0.1940, fr: 10.5795 Hz
# EPOCH 281 VALID) loss: 1.5289, acc: 0.1893, fr: 10.5718 Hz
# EPOCH 282 TRAIN) loss: 1.5289, acc: 0.1893, fr: 10.5718 Hz
# EPOCH 282 VALID) loss: 1.5317, acc: 0.1946, fr: 10.5769 Hz
# EPOCH 283 TRAIN) loss: 1.5317, acc: 0.1946, fr: 10.5769 Hz
# EPOCH 283 VALID) loss: 1.5287, acc: 0.1946, fr: 10.5846 Hz
# EPOCH 284 TRAIN) loss: 1.5287, acc: 0.1946, fr: 10.5846 Hz
# EPOCH 284 VALID) loss: 1.5295, acc: 0.1946, fr: 10.6000 Hz
# EPOCH 285 TRAIN) loss: 1.5295, acc: 0.1946, fr: 10.6000 Hz
# EPOCH 285 VALID) loss: 1.5275, acc: 0.1946, fr: 10.5846 Hz
# EPOCH 286 TRAIN) loss: 1.5275, acc: 0.1946, fr: 10.5846 Hz
# EPOCH 286 VALID) loss: 1.5285, acc: 0.1940, fr: 10.6205 Hz
# EPOCH 287 TRAIN) loss: 1.5285, acc: 0.1940, fr: 10.6205 Hz
# EPOCH 287 VALID) loss: 1.5250, acc: 0.1887, fr: 10.6538 Hz
# EPOCH 288 TRAIN) loss: 1.5250, acc: 0.1887, fr: 10.6538 Hz
# EPOCH 288 VALID) loss: 1.5231, acc: 0.1880, fr: 10.6872 Hz
# EPOCH 289 TRAIN) loss: 1.5231, acc: 0.1880, fr: 10.6872 Hz
# EPOCH 289 VALID) loss: 1.5225, acc: 0.1893, fr: 10.7128 Hz
# EPOCH 290 TRAIN) loss: 1.5225, acc: 0.1893, fr: 10.7128 Hz
# EPOCH 290 VALID) loss: 1.5201, acc: 0.1953, fr: 10.7128 Hz
# EPOCH 291 TRAIN) loss: 1.5201, acc: 0.1953, fr: 10.7128 Hz
# EPOCH 291 VALID) loss: 1.5206, acc: 0.1953, fr: 10.7231 Hz
# EPOCH 292 TRAIN) loss: 1.5206, acc: 0.1953, fr: 10.7231 Hz
# EPOCH 292 VALID) loss: 1.5191, acc: 0.1953, fr: 10.7026 Hz
# EPOCH 293 TRAIN) loss: 1.5191, acc: 0.1953, fr: 10.7026 Hz
# EPOCH 293 VALID) loss: 1.5160, acc: 0.1953, fr: 10.6974 Hz
# EPOCH 294 TRAIN) loss: 1.5160, acc: 0.1953, fr: 10.6974 Hz
# EPOCH 294 VALID) loss: 1.5207, acc: 0.1959, fr: 10.7026 Hz
# EPOCH 295 TRAIN) loss: 1.5207, acc: 0.1959, fr: 10.7026 Hz
# EPOCH 295 VALID) loss: 1.5234, acc: 0.1953, fr: 10.7282 Hz
# EPOCH 296 TRAIN) loss: 1.5234, acc: 0.1953, fr: 10.7282 Hz
# EPOCH 296 VALID) loss: 1.5237, acc: 0.1953, fr: 10.7359 Hz
# EPOCH 297 TRAIN) loss: 1.5237, acc: 0.1953, fr: 10.7359 Hz
# EPOCH 297 VALID) loss: 1.5262, acc: 0.1953, fr: 10.7462 Hz
# EPOCH 298 TRAIN) loss: 1.5262, acc: 0.1953, fr: 10.7462 Hz
# EPOCH 298 VALID) loss: 1.5229, acc: 0.1946, fr: 10.7590 Hz
# EPOCH 299 TRAIN) loss: 1.5229, acc: 0.1946, fr: 10.7590 Hz
# EPOCH 299 VALID) loss: 1.5237, acc: 0.1946, fr: 10.7641 Hz
# EPOCH BEST 227 VALID) loss: 1.5486, acc: 0.2005, fr: 10.1769 Hz

# %% [markdown]
# # Visualization

# %%
######################### visualization #########################
#%% loss, acc, and firing rate as a function of epoch
fig,axes = plt.subplots(1,4,figsize=(10,3),constrained_layout=True, sharex=True)
axes[0].plot(loss_train,label='train')
axes[0].plot(loss_valid,label='valid')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].set_xlabel('Epoch')

axes[1].plot(acc_train)
axes[1].plot(acc_valid)
axes[1].set_ylabel('Acc')
axes[1].set_xlabel('Epoch')

axes[2].plot(fr_train)
axes[2].plot(fr_valid)
axes[2].set_ylabel('firing rate (Hz)')
axes[2].set_xlabel('Epoch')

axes[3].plot(np.abs(wrs).mean(2).mean(1),'k')
axes[3].plot(np.abs(wrs[:,:nb_e,:]).mean(2).mean(1),'r',label='excitatory') #!!! uncomment when using random network
axes[3].plot(np.abs(wrs[:,nb_e:,:]).mean(2).mean(1),'b',label='inhibitory') #!!! uncomment when using random network
axes[3].set_ylabel('|w|')
axes[3].set_xlabel('Epoch')
axes[3].legend()
#%% raster plot
b = 0
fig,axes = plt.subplots(2,4,sharex=True,sharey=True,figsize=(20,4))
axes = axes.flatten()
for j in range(8):
    spktr_tmp = spktr[N*j]
    spk4.rasterplot(spktr_tmp, ax=axes[j])
    axes[j].plot(nb_hidden/2+10*stim[-1,b],'r')
    axes[j].axis('off')
    axes[j].set_title('epoch %d' %(N*j))

fig = plt.figure(figsize=(6,3),constrained_layout=True)
spk4.rasterplot(x_batch[b], fs=0, markersize=3, t0=0, color='k')
plt.axhline(y=10,linestyle=':',c='k')
plt.axhline(y=20,linestyle=':',c='k')
plt.axhline(y=30,linestyle=':',c='k')
plt.xlabel('Time (ms)')
plt.ylabel('neuron index')
plt.savefig('raster.png')
#%% weight matrix plot
fig,axes = plt.subplots(2,4,constrained_layout=True,figsize=(10,5))
axes = axes.flatten()
cmax = 2*np.std(np.abs(wrs))
for j in range(8):
    im = axes[j].imshow(wrs[N*j], vmin=-cmax, vmax=cmax, cmap='jet')
    axes[j].set_title('epoch %d' %(N*j))
plt.colorbar(im, ax=axes[-1])
plt.savefig('weight_matrix.png')
#%% weight distribution
fig,axes = plt.subplots(2,4,constrained_layout=True,figsize=(10,5),sharex=True,sharey=True)
axes = axes.flatten()
wmax = 3*np.std(wrs)
for j in range(8):
    axes[j].hist(wrs[N*j].flatten(),bins=np.linspace(-wmax, wmax, 30),color='gray')
    axes[j].axvline(x=0,c='k',linestyle=':')
plt.savefig('weight_dist.png')
#%% save weights
import pickle
fname = r'weight_lr_v2.pkl'
file = open(fname, "wb")
dict_data = {'w1':w1_save, 'w2':w2_save, 'wr':wr_save, 'bias':bias_save}
pickle.dump(dict_data, file)
file.close()
#%% example trace and raster
b = 0
fig,axes = plt.subplots(3,1,figsize=(6,5),constrained_layout=True, sharex=True)
spk4.rasterplot(x_batch[b], fs=0, markersize=3, t0=0, color='k', nrn0=0, ax=axes[0])
axes[0].axhline(y=10,linestyle=':',c='k')
axes[0].axhline(y=20,linestyle=':',c='k')
axes[0].axhline(y=30,linestyle=':',c='k')
axes[0].set_title('input layer')
axes[0].set_ylabel('neuron index')

spk4.rasterplot(spktr[epoch_best], ax=axes[1])
axes[1].set_title('recurrent layer')
axes[1].set_ylabel('neuron index')

# axes[0].set_title('pred: %d vs. target: %d' %(np.argmax(pi[b]), y[b,-1]))
axes[2].plot(atr[epoch_best,:,:8])
axes[2].set_title('a trace')
axes[2].set_ylabel('self-inhibition (a.u.)')
axes[2].set_xlabel('Time (ms)')

plt.savefig('trace_raster.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ce8791a0bb5e> in <module>
#       2 #%% loss, acc, and firing rate as a function of epoch
#       3 fig,axes = plt.subplots(1,4,figsize=(10,3),constrained_layout=True, sharex=True)
# ----> 4 axes[0].plot(loss_train,label='train')
#       5 axes[0].plot(loss_valid,label='valid')
#       6 axes[0].set_ylabel('Loss')
#
# NameError: name 'loss_train' is not defined
