# %%
# !pip install mpi4py

# %%
# !python drive/MyDrive/eecs545.lnk/eprop-reinforcement-learning/antv2/sac/model.py
# Out:
# 2021-04-09 01:17:22.534925: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Logging data to /content/drive/MyDrive/1.2 BME SUGS/winter_2021_classes/eecs545/eprop-reinforcement-learning/antv2/data/sac/sac_s0/progress.txt
# Saving config:
#
# {
#     "actor_critic_function":	"actor_critic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "env_name":	"Pendulum-v0",
#     "epochs":	50,
#     "exp_name":	"sac",
#     "gamma":	0.99,
#     "hidden_size":	[
#         300
#     ],
#     "logger":	{
#         "<utils.EpochLogger object at 0x7fb040948550>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/content/drive/MyDrive/1.2 BME SUGS/winter_2021_classes/eecs545/eprop-reinforcement-learning/antv2/data/sac/sac_s0",
#             "output_file":	{
# ...
